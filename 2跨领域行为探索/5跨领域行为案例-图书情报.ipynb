# %%
import pickle as pk
from tqdm import tqdm
START_YAER = 1800
END_YAER = 2021
CUT_YEAR_COUNT = 3
NO_CUT_YEAR = 100
print('参数设置: START_YAER: %d, END_YAER: %d, CUT_YEAR_COUNT: %d'%(START_YAER, END_YAER, CUT_YEAR_COUNT))
LIS = 'Information Science & Library Science'.upper()
# Out:
# 参数设置: START_YAER: 1800, END_YAER: 2021, CUT_YEAR_COUNT: 3

# %%
# 1800至2021年，生涯长度2年及以上的研究者，图情领域转入转出的研究者
for cutyearCount in range(2,CUT_YEAR_COUNT,1):
    # KeyInitialSetCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/KeyInitialSetCounter%d_%d_True%dCut.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    # KeyNoBreakthroughCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/KeyNoBreakthroughCounter%d_%d_True%dCut.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    KeyBreakthroughCombineCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/KeyBreakthroughCombineCounter%d_%d_True%dCut全生涯.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    # FirstInitialSetCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/FirstInitialSetCounter%d_%d_True%dCut.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    # FirstNoBreakthroughCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/FirstNoBreakthroughCounter%d_%d_True%dCut.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    FirstBreakthroughCombineCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/FirstBreakthroughCombineCounter%d_%d_True%dCut全生涯.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    # LastInitialSetCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/LastInitialSetCounter%d_%d_True%dCut.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    # LastNoBreakthroughCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/LastNoBreakthroughCounter%d_%d_True%dCut.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    LastBreakthroughCombineCounter=pk.load( open('../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/LastBreakthroughCombineCounter%d_%d_True%dCut全生涯.pk'%(START_YAER,END_YAER,cutyearCount), 'rb'))
    try:
        print('KeyBreakthroughCombineCounter:',len(KeyBreakthroughCombineCounter))
        InNumCount = 0
        OutNumCount = 0
        InFieldNumCount = 0
        OutFieldNumCount = 0
        for item in sorted(KeyBreakthroughCombineCounter.items(),key=lambda x:-x[1]):
            if LIS in item[0]:
                # 迁出
                if LIS in item[0].split('------')[0]:
                    OutNumCount += 1
                    OutFieldNumCount += item[1]
                # 迁入
                else:
                    InNumCount += 1
                    InFieldNumCount += item[1]
                if item[1] > 1:
                    print(item)
        print('#Num: 迁入KeyBreakthroughCombine学科组合数',InNumCount)
        print('#Num: 迁出KeyBreakthroughCombine学科组合数',OutNumCount)
        print('#Num: 迁入KeyBreakthroughCombine作者数',InFieldNumCount)
        print('#Num: 迁出KeyBreakthroughCombine作者数',OutFieldNumCount)
    except:
        pass
    print('======\n')
    # try:
    #     print('KeyInitialSetCounter:',len(KeyInitialSetCounter))
    #     for i in range(100):
    #         print(sorted(KeyInitialSetCounter.items(),key=lambda x:-x[1])[i])
    # except:
    #     pass
    #     print('======\n')
    # try:
    #     print('KeyNoBreakthroughCounter:',len(KeyNoBreakthroughCounter))
    #     for i in range(100):
    #         print(sorted(KeyNoBreakthroughCounter.items(),key=lambda x:-x[1])[i])
    # except:
    #     pass
    #     print('======\n\n\n\n')
    try:
        print('FirstBreakthroughCombineCounter:',len(FirstBreakthroughCombineCounter))
        InNumCount = 0
        OutNumCount = 0
        InFieldNumCount = 0
        OutFieldNumCount = 0
        for item in sorted(FirstBreakthroughCombineCounter.items(),key=lambda x:-x[1]):
            if LIS in item[0]:
                # 迁出
                if LIS in item[0].split('------')[0]:
                    OutNumCount += 1
                    OutFieldNumCount += item[1]
                # 迁入
                else:
                    InNumCount += 1
                    InFieldNumCount += item[1]
                if item[1] > 1:
                    print(item)
        print('#Num: 迁入FirstBreakthroughCombine学科组合数',InNumCount)
        print('#Num: 迁出FirstBreakthroughCombine学科组合数',OutNumCount)
        print('#Num: 迁入FirstBreakthroughCombine作者数',InFieldNumCount)
        print('#Num: 迁出FirstBreakthroughCombine作者数',OutFieldNumCount)
    except:
        pass
    print('======\n')
    # try:
    #     print('FirstInitialSetCounter:',len(FirstInitialSetCounter))
    #     for i in range(100):
    #         print(sorted(FirstInitialSetCounter.items(),key=lambda x:-x[1])[i])
    # except:
    #     pass
    #     print('======\n')
    # try:
    #     print('FirstNoBreakthroughCounter:',len(FirstNoBreakthroughCounter))
    #     for i in range(100):
    #         print(sorted(FirstNoBreakthroughCounter.items(),key=lambda x:-x[1])[i])
    # except:
    #     pass
    #     print('======\n\n\n\n')
    try:
        print('LastBreakthroughCombineCounter:',len(LastBreakthroughCombineCounter))
        InNumCount = 0
        OutNumCount = 0
        InFieldNumCount = 0
        OutFieldNumCount = 0
        for item in sorted(LastBreakthroughCombineCounter.items(),key=lambda x:-x[1]):
            if LIS in item[0]:
                # 迁出
                if LIS in item[0].split('------')[0]:
                    OutNumCount += 1
                    OutFieldNumCount += item[1]
                # 迁入
                else:
                    InNumCount += 1
                    InFieldNumCount += item[1]
                if item[1] > 1:
                    print(item)
        print('#Num: 迁入LastBreakthroughCombine学科组合数',InNumCount)
        print('#Num: 迁出LastBreakthroughCombine学科组合数',OutNumCount)
        print('#Num: 迁入LastBreakthroughCombine作者数',InFieldNumCount)
        print('#Num: 迁出LastBreakthroughCombine作者数',OutFieldNumCount)
    except:
        pass
    print('======\n')
    # try:
    #     print('LastInitialSetCounter:',len(LastInitialSetCounter))
    #     for i in range(100):
    #         print(sorted(LastInitialSetCounter.items(),key=lambda x:-x[1])[i])
    # except:
    #     pass
    #     print('======\n')
    # try:
    #     print('LastNoBreakthroughCounter:',len(LastNoBreakthroughCounter))
    #     for i in range(100):
    #         print(sorted(LastNoBreakthroughCounter.items(),key=lambda x:-x[1])[i])
    # except:
    #     pass
    #     print('======\n\n\n\n')
# Out:
# KeyBreakthroughCombineCounter: 636197
# ('INFORMATION SCIENCE & LIBRARY SCIENCE------EDUCATION & EDUCATIONAL RESEARCH', 173)
# ('EDUCATION & EDUCATIONAL RESEARCH------INFORMATION SCIENCE & LIBRARY SCIENCE', 169)
# ('BUSINESS $$ MANAGEMENT------INFORMATION SCIENCE & LIBRARY SCIENCE', 153)
# ('COMPUTER SCIENCE, INFORMATION SYSTEMS $$ INFORMATION SCIENCE & LIBRARY SCIENCE $$ MANAGEMENT------COMPUTER SCIENCE, HARDWARE & ARCHITECTURE $$ COMPUTER SCIENCE, SOFTWARE ENGINEERING $$ COMPUTER SCIENCE, THEORY & METHODS', 123)
# ('COMMUNICATION------INFORMATION SCIENCE & LIBRARY SCIENCE', 115)
# ('ECONOMICS------COMMUNICATION $$ INFORMATION SCIENCE & LIBRARY SCIENCE $$ TELECOMMUNICATIONS', 112)
# ('INFORMATION SCIENCE & LIBRARY SCIENCE------COMPUTER SCIENCE, INFORMATION SYSTEMS', 97)
# ('COMPUTER SCIENCE, INFORMATION SYSTEMS $$ INFORMATION SCIENCE & LIBRARY SCIENCE $$ MANAGEMENT------BUSINESS', 91)
# ...
