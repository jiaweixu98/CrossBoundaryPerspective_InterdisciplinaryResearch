# %% [markdown]
# # MAG中收录的期刊的基本特征

# %%
import pickle as pk
from collections import Counter
import numpy as np
# plot 同时中英混排
import matplotlib.pyplot as plt
from matplotlib import font_manager
plt.style.use('seaborn')
plt.figure(figsize=(4,3), dpi=300)
# 字体加载
font_path = "../../../font/tnw+simsun.ttf"
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
# 字体设置
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()  # 根据名称设置字体
plt.rcParams['font.size'] = 24 # 设置字体大小
plt.rcParams['axes.unicode_minus'] = False # 使坐标轴刻度标签正常显示正负号
# Out:
# C:\Users\jiawei\AppData\Local\Temp\ipykernel_33680\2051212305.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# # journal_cate key: mag journal id. values: a dictionary containing the metadata of the journals. e.g. jcrCate, jcrName, JCI, JIF
journal_cate = pk.load(open('../../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/journal_cate.pkl','rb'))

# %%
count = 10
for k,v in journal_cate.items():
    # print(v['jcrCate'].split('$'))
    print(v)
    count -= 1
    if count == 0:
        break
# Out:
# {'jcrCate': 'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS - SCIE$STATISTICS & PROBABILITY - SCIE$DEMOGRAPHY - SSCI$SOCIAL SCIENCES, MATHEMATICAL METHODS - SSCI', 'jcrName': 'Mathematical Population Studies', 'magName': 'mathematical population studies', 'magIssn': ['0889-8480', '0889-8480', '1547-724X'], 'jcrIssn': '0889-8480', 'jcrEIssn': '1547-724X', '2021-JIF': '1.355', '2021-Qscie': 'Q3', '2021-Qssci': 'Q4', '2021-Qahci': 'N/A', '2021-JCI': '0.38'}
# {'jcrCate': 'MINERALOGY - SCIE', 'jcrName': 'Journal of Mineralogical and Petrological Sciences', 'magName': 'journal of mineralogical and petrological sciences', 'magIssn': ['1345-6296', '1349-3825', '1345-6296'], 'jcrIssn': '1345-6296', 'jcrEIssn': '1349-3825', '2021-JIF': '1.041', '2021-Qscie': 'Q4', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.30'}
# {'jcrCate': 'ONCOLOGY - SCIE$RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING - SCIE', 'jcrName': 'STRAHLENTHERAPIE UND ONKOLOGIE', 'magName': 'strahlentherapie und onkologie', 'magIssn': ['0179-7158', '0179-7158', '1439-099X'], 'jcrIssn': '0179-7158', 'jcrEIssn': '1439-099X', '2021-JIF': '4.033', '2021-Qscie': 'Q2', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.79'}
# {'jcrCate': 'MEDICINE, RESEARCH & EXPERIMENTAL - SCIE', 'jcrName': 'M S-MEDECINE SCIENCES', 'magName': 'm s medecine sciences', 'magIssn': ['0767-0974', '0767-0974', '1958-5381'], 'jcrIssn': '0767-0974', 'jcrEIssn': '1958-5381', '2021-JIF': '0.716', '2021-Qscie': 'Q4', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.13'}
# {'jcrCate': 'PATHOLOGY - SCIE$SURGERY - SCIE', 'jcrName': 'AMERICAN JOURNAL OF SURGICAL PATHOLOGY', 'magName': 'the american journal of surgical pathology', 'magIssn': ['0147-5185', '1532-0979', '0147-5185'], 'jcrIssn': '0147-5185', 'jcrEIssn': '1532-0979', '2021-JIF': '6.298', '2021-Qscie': 'Q1', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '2.24'}
# {'jcrCate': 'ECOLOGY - SCIE$EVOLUTIONARY BIOLOGY - SCIE$GENETICS & HEREDITY - SCIE', 'jcrName': 'HEREDITY', 'magName': 'heredity', 'magIssn': ['0018-067X', '0018-067X', '1365-2540'], 'jcrIssn': '0018-067X', 'jcrEIssn': '1365-2540', '2021-JIF': '3.832', '2021-Qscie': 'Q2', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.92'}
# {'jcrCate': 'CELL & TISSUE ENGINEERING - SCIE$CELL BIOLOGY - SCIE', 'jcrName': 'Cell Stem Cell', 'magName': 'cell stem cell', 'magIssn': ['1875-9777', '1934-5909', '1875-9777'], 'jcrIssn': '1934-5909', 'jcrEIssn': '1875-9777', '2021-JIF': '25.269', '2021-Qscie': 'Q1', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '4.15'}
# {'jcrCate': 'MICROBIOLOGY - SCIE', 'jcrName': 'PROTIST', 'magName': 'protist', 'magIssn': ['1434-4610', '1434-4610', '1618-0941'], 'jcrIssn': '1434-4610', 'jcrEIssn': '1618-0941', '2021-JIF': '2.656', '2021-Qscie': 'Q4', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.56'}
# {'jcrCate': 'MATHEMATICS - SCIE', 'jcrName': 'INVENTIONES MATHEMATICAE', 'magName': 'inventiones mathematicae', 'magIssn': ['0020-9910', '0020-9910', '1432-1297'], 'jcrIssn': '0020-9910', 'jcrEIssn': '1432-1297', '2021-JIF': '3.128', '2021-Qscie': 'Q1', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '2.74'}
# {'jcrCate': 'FORESTRY - SCIE', 'jcrName': 'Austrian Journal of Forest Science', 'magName': 'austrian journal of forest science', 'magIssn': ['0379-5292', '0379-5292'], 'jcrIssn': '0379-5292', 'jcrEIssn': '0375-524X', '2021-JIF': '1.143', '2021-Qscie': 'Q4', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.41'}

# %%
# 检查基本数据,命名很规范
for k,v in journal_cate.items():
    for field in v['jcrCate'].split('$'):
        if field[-4:] not in ['SCIE','SSCI','AHCI']:
            print(field[-4:])

# %% [markdown]
# 共有1万3千本期刊, 数量上看单学科期刊有多少本.多学科期刊有多少本
#
# 还需要看期刊分类粒度.

# %%
# 期刊数量分布
numJournalCateCounter = Counter()
for k,v in journal_cate.items():
    numJournalCateCounter[len(v['jcrCate'].split('$'))] += 1
print(numJournalCateCounter)
numFields , frequency = zip(*numJournalCateCounter.items())
print(numFields, frequency)
# Out:
# Counter({1: 7618, 2: 4339, 3: 1343, 4: 392, 5: 56, 6: 13, 8: 1})
# (4, 1, 2, 3, 5, 6, 8) (392, 7618, 4339, 1343, 56, 13, 1)

# %%
fig, ax = plt.subplots()
bars = ax.bar(numFields, frequency)
ax.bar_label(bars)
ax.set_ylabel('期刊数量(本)', font=prop.get_name())
ax.set_xlabel('一本期刊所跨JCR学科数量(个)', font=prop.get_name())
ax.set_title('期刊所跨JCR学科数量分布', font=prop.get_name())
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)
plt.text(-0.1,1.05,'(A)', color = 'red',
horizontalalignment='center',verticalalignment='center',
transform=ax.transAxes)
plt.show()
fig.savefig("期刊所跨JCR学科数量分布.png",dpi=300,bbox_inches='tight')

# %% [markdown]
# 注意，这里的JCR学科数量带索引后缀，例如'mathematics-scie'. 后面去掉了后缀。
#
# 跨不同学科的情况,下面看跨不同检索大类的情况.

# %%
# 输出这个跨了几个Index,1-3皆有可能.
def index_count(FieldList):
    index_set = set()
    for field in FieldList:
        index_set.add(field[-4:])
    return len(index_set)

# %%
# 从SSCI, SCIE, AHCI期刊数量分布
numJournalIndexCounter = Counter()
for k,v in journal_cate.items():
    numJournalIndexCounter[index_count(v['jcrCate'].split('$'))] += 1
    if index_count(v['jcrCate'].split('$')) == 3:
        print(v['2021-JIF'], v['jcrName'] ,'=============================',v['jcrCate'], )
print(numJournalIndexCounter)
numIndex , frequency = zip(*sorted(numJournalIndexCounter.items()))
numIndex = list(map(str,numIndex))
print(numIndex, frequency)
# Out:
# 0.964 Studies in History and Philosophy of Science Part C-Studies in History and Philosophy of Biological and Biomedical Sciences ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 3.282 BRITISH JOURNAL FOR THE PHILOSOPHY OF SCIENCE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 2.213 Archaeological and Anthropological Sciences ============================= GEOSCIENCES, MULTIDISCIPLINARY - SCIE$ARCHAEOLOGY - AHCI$ANTHROPOLOGY - SSCI
# 0.415 SCIENCE IN CONTEXT ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.841 Natural Language Engineering ============================= COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE - SCIE$LANGUAGE & LINGUISTICS - AHCI$LINGUISTICS - SSCI
# 0.306 HISTORIA MATHEMATICA ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$MATHEMATICS - SCIE$MATHEMATICS, INTERDISCIPLINARY APPLICATIONS - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.752 PHILOSOPHY OF SCIENCE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.795 BIOLOGY & PHILOSOPHY ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.379 STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 2.200 Philosophy Ethics and Humanities in Medicine ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$MEDICAL ETHICS - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$PHILOSOPHY - AHCI$ETHICS - SSCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.548 Historical Studies in the Natural Sciences ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.037 HISTORY OF SCIENCE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.591 HISTORY OF THE HUMAN SCIENCES ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI$HISTORY OF SOCIAL SCIENCES - SSCI
# 1.198 CENTAURUS ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.514 ISIS ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.500 Berichte zur Wissenschaftsgeschichte ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.188 Nuncius-Journal of the History of Science ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.735 Biosemiotics ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HUMANITIES, MULTIDISCIPLINARY - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.343 ANNALS OF SCIENCE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.818 JOURNAL OF THE HISTORY OF BIOLOGY ============================= BIOLOGY - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 2.781 SOCIAL STUDIES OF SCIENCE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 2.921 Science & Education ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$EDUCATION & EDUCATIONAL RESEARCH - SSCI
# 0.424 OSIRIS ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.324 PHONETICA ============================= ACOUSTICS - SCIE$AUDIOLOGY & SPEECH-LANGUAGE PATHOLOGY - SCIE$LANGUAGE & LINGUISTICS - AHCI$LINGUISTICS - SSCI
# 0.462 AGRICULTURAL HISTORY ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI$HISTORY - SSCI
# 1.595 SYNTHESE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$PHILOSOPHY - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.832 SOCIAL HISTORY OF MEDICINE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI$HISTORY - SSCI
# 2.367 JOURNAL OF AGRICULTURAL & ENVIRONMENTAL ETHICS ============================= AGRICULTURE, MULTIDISCIPLINARY - SCIE$ENVIRONMENTAL SCIENCES - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$ETHICS - SSCI
# 0.545 Dynamis ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 0.659 BULLETIN OF THE HISTORY OF MEDICINE ============================= HEALTH CARE SCIENCES & SERVICES - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 9.194 Transactions of the Association for Computational Linguistics ============================= COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE - SCIE$LANGUAGE & LINGUISTICS - AHCI$LINGUISTICS - SSCI
# 0.645 TECHNOLOGY AND CULTURE ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.568 MEDICAL HISTORY ============================= HEALTH CARE SCIENCES & SERVICES - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 7.778 COMPUTATIONAL LINGUISTICS ============================= COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE - SCIE$COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS - SCIE$LANGUAGE & LINGUISTICS - AHCI$LINGUISTICS - SSCI
# 0.909 JOURNAL OF THE HISTORY OF MEDICINE AND ALLIED SCIENCES ============================= HEALTH CARE SCIENCES & SERVICES - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 1.512 International Journal of Design ============================= ENGINEERING, MANUFACTURING - SCIE$ENGINEERING, MULTIDISCIPLINARY - SCIE$ART - AHCI$SOCIAL SCIENCES, INTERDISCIPLINARY - SSCI
# 1.452 HISTORY AND PHILOSOPHY OF THE LIFE SCIENCES ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# 3.508 JOURNAL OF ARCHAEOLOGICAL SCIENCE ============================= GEOSCIENCES, MULTIDISCIPLINARY - SCIE$ARCHAEOLOGY - AHCI$ANTHROPOLOGY - SSCI
# 0.236 ARCHIVES OF NATURAL HISTORY ============================= HISTORY & PHILOSOPHY OF SCIENCE - SCIE$HISTORY & PHILOSOPHY OF SCIENCE - AHCI$HISTORY & PHILOSOPHY OF SCIENCE - SSCI
# Counter({1: 12655, 2: 1068, 3: 39})
# ['1', '2', '3'] (12655, 1068, 39)

# %% [markdown]
# 还是有1000多本期刊是双期刊收录的,3本是3期刊收录的, 看上去基本是研究某个领域的历史. 或者哲学什么的. 技术哲学, 还有自然语言处理， 设计学，考古学等。

# %%
fig, ax = plt.subplots()
bars = ax.bar(numIndex, frequency)
ax.bar_label(bars)
ax.set_ylabel('期刊数量(本)', font=prop.get_name())
ax.set_xlabel('一本期刊所跨索引数量(SCIE, SSCI, ACHI)(个)', font=prop.get_name())
ax.set_title('期刊所跨索引数量分布', font=prop.get_name())
ax.xaxis.set_tick_params(labelsize=24)
ax.yaxis.set_tick_params(labelsize=24)
plt.text(-0.1,1.05,'(B)', color = 'red',
horizontalalignment='center',verticalalignment='center',
transform=ax.transAxes)
plt.show()
fig.savefig("期刊所跨索引数量分布.png",dpi=300, bbox_inches='tight')

# %% [markdown]
# 下面看SCIE, SSCI, AHCI三类. 具体的分类情况

# %%
#全部期刊的情况
numCateCounter = Counter()
for k,v in journal_cate.items():
    for field in v['jcrCate'].split('$'):
        numCateCounter[field[:-7]] += 1
print(numCateCounter)
numIndex , frequency = zip(*sorted(numCateCounter.items()))
print(numIndex, frequency)
print(len(numIndex))
# Out:
# Counter({'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH': 392, 'HISTORY': 387, 'ECONOMICS': 382, 'MATERIALS SCIENCE, MULTIDISCIPLINARY': 346, 'MATHEMATICS': 332, 'PSYCHIATRY': 299, 'BIOCHEMISTRY & MOLECULAR BIOLOGY': 296, 'ENVIRONMENTAL SCIENCES': 278, 'PHARMACOLOGY & PHARMACY': 278, 'ENGINEERING, ELECTRICAL & ELECTRONIC': 278, 'NEUROSCIENCES': 272, 'EDUCATION & EDUCATIONAL RESEARCH': 270, 'MATHEMATICS, APPLIED': 267, 'NURSING': 248, 'ONCOLOGY': 245, 'PLANT SCIENCES': 237, 'MANAGEMENT': 228, 'SURGERY': 214, 'CLINICAL NEUROLOGY': 212, 'GEOSCIENCES, MULTIDISCIPLINARY': 202, 'LANGUAGE & LINGUISTICS': 202, 'CELL BIOLOGY': 194, 'LINGUISTICS': 194, 'POLITICAL SCIENCE': 188, 'PHILOSOPHY': 187, 'CHEMISTRY, MULTIDISCIPLINARY': 179, 'GENETICS & HEREDITY': 177, 'ZOOLOGY': 175, 'ECOLOGY': 174, 'HISTORY & PHILOSOPHY OF SCIENCE': 174, 'MEDICINE, GENERAL & INTERNAL': 172, 'CHEMISTRY, PHYSICAL': 165, 'COMPUTER SCIENCE, INFORMATION SYSTEMS': 164, 'IMMUNOLOGY': 163, 'PHYSICS, APPLIED': 161, 'BIOTECHNOLOGY & APPLIED MICROBIOLOGY': 160, 'BUSINESS': 155, 'LAW': 153, 'RELIGION': 150, 'SOCIOLOGY': 150, 'PSYCHOLOGY, MULTIDISCIPLINARY': 149, 'HUMANITIES, MULTIDISCIPLINARY': 149, 'ENDOCRINOLOGY & METABOLISM': 147, 'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE': 146, 'VETERINARY SCIENCES': 145, 'FOOD SCIENCE & TECHNOLOGY': 144, 'ENGINEERING, CHEMICAL': 143, 'CARDIAC & CARDIOVASCULAR SYSTEMS': 142, 'REHABILITATION': 141, 'MEDICINE, RESEARCH & EXPERIMENTAL': 140, 'MICROBIOLOGY': 138, 'MECHANICS': 138, 'ENGINEERING, CIVIL': 137, 'ENGINEERING, MECHANICAL': 137, 'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING': 136, 'PSYCHOLOGY, CLINICAL': 132, 'PEDIATRICS': 130, 'ENVIRONMENTAL STUDIES': 128, 'STATISTICS & PROBABILITY': 125, 'LITERATURE': 122, 'ENERGY & FUELS': 119, 'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS': 112, 'MARINE & FRESHWATER BIOLOGY': 112, 'COMPUTER SCIENCE, THEORY & METHODS': 111, 'BUSINESS, FINANCE': 111, 'SOCIAL SCIENCES, INTERDISCIPLINARY': 111, 'COMPUTER SCIENCE, SOFTWARE ENGINEERING': 110, 'NANOSCIENCE & NANOTECHNOLOGY': 110, 'HEALTH CARE SCIENCES & SERVICES': 109, 'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS': 108, 'ARCHAEOLOGY': 106, 'OPTICS': 102, 'ENTOMOLOGY': 100, 'WATER RESOURCES': 100, 'ENGINEERING, BIOMEDICAL': 98, 'INFECTIOUS DISEASES': 96, 'COMMUNICATION': 96, 'INTERNATIONAL RELATIONS': 96, 'METEOROLOGY & ATMOSPHERIC SCIENCES': 94, 'TOXICOLOGY': 94, 'TELECOMMUNICATIONS': 93, 'GASTROENTEROLOGY & HEPATOLOGY': 93, 'BIOLOGY': 93, 'ANTHROPOLOGY': 93, 'DENTISTRY, ORAL SURGERY & MEDICINE': 92, 'ENGINEERING, MULTIDISCIPLINARY': 91, 'PSYCHOLOGY, EXPERIMENTAL': 91, 'AGRONOMY': 90, 'POLYMER SCIENCE': 90, 'UROLOGY & NEPHROLOGY': 90, 'NUTRITION & DIETETICS': 90, 'HEALTH POLICY & SERVICES': 88, 'SPORT SCIENCES': 88, 'GEOCHEMISTRY & GEOPHYSICS': 87, 'OPERATIONS RESEARCH & MANAGEMENT SCIENCE': 87, 'CHEMISTRY, ANALYTICAL': 86, 'ORTHOPEDICS': 86, 'PHYSICS, MULTIDISCIPLINARY': 86, 'GEOGRAPHY': 86, 'CULTURAL STUDIES': 86, 'OBSTETRICS & GYNECOLOGY': 85, 'INFORMATION SCIENCE & LIBRARY SCIENCE': 84, 'AREA STUDIES': 84, 'PSYCHOLOGY, APPLIED': 82, 'PHYSIOLOGY': 81, 'PSYCHOLOGY, DEVELOPMENTAL': 80, 'PSYCHOLOGY': 79, 'METALLURGY & METALLURGICAL ENGINEERING': 79, 'HEMATOLOGY': 79, 'BIOCHEMICAL RESEARCH METHODS': 79, 'MUSIC': 78, 'ART': 78, 'PATHOLOGY': 77, 'CHEMISTRY, APPLIED': 73, 'MULTIDISCIPLINARY SCIENCES': 72, 'BIOPHYSICS': 72, 'FORESTRY': 70, 'DERMATOLOGY': 70, 'CRIMINOLOGY & PENOLOGY': 70, 'PHYSICS, CONDENSED MATTER': 69, 'ASTRONOMY & ASTROPHYSICS': 69, 'CONSTRUCTION & BUILDING TECHNOLOGY': 68, 'PERIPHERAL VASCULAR DISEASE': 67, 'OCEANOGRAPHY': 66, 'RESPIRATORY SYSTEM': 66, 'ASIAN STUDIES': 66, 'PSYCHOLOGY, SOCIAL': 66, 'AUTOMATION & CONTROL SYSTEMS': 65, 'BIODIVERSITY CONSERVATION': 65, 'INSTRUMENTS & INSTRUMENTATION': 63, 'THERMODYNAMICS': 63, 'CHEMISTRY, MEDICINAL': 62, 'OPHTHALMOLOGY': 62, 'LITERATURE, ROMANCE': 62, 'AGRICULTURE, DAIRY & ANIMAL SCIENCE': 61, 'PSYCHOLOGY, EDUCATIONAL': 61, 'AGRICULTURE, MULTIDISCIPLINARY': 60, 'HOSPITALITY, LEISURE ...
# ('ACOUSTICS', 'AGRICULTURAL ECONOMICS & POLICY', 'AGRICULTURAL ENGINEERING', 'AGRICULTURE, DAIRY & ANIMAL SCIENCE', 'AGRICULTURE, MULTIDISCIPLINARY', 'AGRONOMY', 'ALLERGY', 'ANATOMY & MORPHOLOGY', 'ANDROLOGY', 'ANESTHESIOLOGY', 'ANTHROPOLOGY', 'ARCHAEOLOGY', 'ARCHITECTURE', 'AREA STUDIES', 'ART', 'ASIAN STUDIES', 'ASTRONOMY & ASTROPHYSICS', 'AUDIOLOGY & SPEECH-LANGUAGE PATHOLOGY', 'AUTOMATION & CONTROL SYSTEMS', 'BEHAVIORAL SCIENCES', 'BIOCHEMICAL RESEARCH METHODS', 'BIOCHEMISTRY & MOLECULAR BIOLOGY', 'BIODIVERSITY CONSERVATION', 'BIOLOGY', 'BIOPHYSICS', 'BIOTECHNOLOGY & APPLIED MICROBIOLOGY', 'BUSINESS', 'BUSINESS, FINANCE', 'CARDIAC & CARDIOVASCULAR SYSTEMS', 'CELL & TISSUE ENGINEERING', 'CELL BIOLOGY', 'CHEMISTRY, ANALYTICAL', 'CHEMISTRY, APPLIED', 'CHEMISTRY, INORGANIC & NUCLEAR', 'CHEMISTRY, MEDICINAL', 'CHEMISTRY, MULTIDISCIPLINARY', 'CHEMISTRY, ORGANIC', 'CHEMISTRY, PHYSICAL', 'CLASSICS', 'CLINICAL NEUROLOGY', 'COMMUNICATION', 'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE', 'COMPUTER SCIENCE, CYBERNETICS', 'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE', 'COMPUTER SCIENCE, INFORMATION SYSTEMS', 'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS', 'COMPUTER SCIENCE, SOFTWARE ENGINEERING', 'COMPUTER SCIENCE, THEORY & METHODS', 'CONSTRUCTION & BUILDING TECHNOLOGY', 'CRIMINOLOGY & PENOLOGY', 'CRITICAL CARE MEDICINE', 'CRYSTALLOGRAPHY', 'CULTURAL STUDIES', 'DANCE', 'DEMOGRAPHY', 'DENTISTRY, ORAL SURGERY & MEDICINE', 'DERMATOLOGY', 'DEVELOPMENT STUDIES', 'DEVELOPMENTAL BIOLOGY', 'ECOLOGY', 'ECONOMICS', 'EDUCATION & EDUCATIONAL RESEARCH', 'EDUCATION, SCIENTIFIC DISCIPLINES', 'EDUCATION, SPECIAL', 'ELECTROCHEMISTRY', 'EMERGENCY MEDICINE', 'ENDOCRINOLOGY & METABOLISM', 'ENERGY & FUELS', 'ENGINEERING, AEROSPACE', 'ENGINEERING, BIOMEDICAL', 'ENGINEERING, CHEMICAL', 'ENGINEERING, CIVIL', 'ENGINEERING, ELECTRICAL & ELECTRONIC', 'ENGINEERING, ENVIRONMENTAL', 'ENGINEERING, GEOLOGICAL', 'ENGINEERING, INDUSTRIAL', 'ENGINEERING, MANUFACTURING', 'ENGINEERING, MARINE', 'ENGINEERING, MECHANICAL', 'ENGINEERING, MULTIDISCIPLINARY', 'ENGINEERING, OCEAN', 'ENGINEERING, PETROLEUM', 'ENTOMOLOGY', 'ENVIRONMENTAL SCIENCES', 'ENVIRONMENTAL STUDIES', 'ERGONOMICS', 'ETHICS', 'ETHNIC STUDIES', 'EVOLUTIONARY BIOLOGY', 'FAMILY STUDIES', 'FILM, RADIO, TELEVISION', 'FISHERIES', 'FOLKLORE', 'FOOD SCIENCE & TECHNOLOGY', 'FORESTRY', 'GASTROENTEROLOGY & HEPATOLOGY', 'GENETICS & HEREDITY', 'GEOCHEMISTRY & GEOPHYSICS', 'GEOGRAPHY', 'GEOGRAPHY, PHYSICAL', 'GEOLOGY', 'GEOSCIENCES, MULTIDISCIPLINARY', 'GERIATRICS & GERONTOLOGY', 'GERONTOLOGY', 'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY', 'HEALTH CARE SCIENCES & SERVICES', 'HEALTH POLICY & SERVICES', 'HEMATOLOGY', 'HISTORY', 'HISTORY & PHILOSOPHY OF SCIENCE', 'HISTORY OF SOCIAL SCIENCES', 'HORTICULTURE', 'HOSPITALITY, LEISURE, SPORT & TOURISM', 'HUMANITIES, MULTIDISCIPLINARY', 'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY', 'IMMUNOLOGY', 'INDUSTRIAL RELATIONS & LABOR', 'INFECTIOUS DISEASES', 'INFORMATION SCIENCE & LIBRARY SCIENCE', 'INSTRUMENTS & INSTRUMENTATION', 'INTEGRATIVE & COMPLEMENTARY MEDICINE', 'INTERNATIONAL RELATIONS', 'LANGUAGE & LINGUISTICS', 'LAW', 'LIMNOLOGY', 'LINGUISTICS', 'LITERARY REVIEWS', 'LITERARY THEORY & CRITICISM', 'LITERATURE', 'LITERATURE, AFRICAN, AUSTRALIAN, CANADIAN', 'LITERATURE, AMERICAN', 'LITERATURE, BRITISH ISLES', 'LITERATURE, GERMAN, DUTCH, SCANDINAVIAN', 'LITERATURE, ROMANCE', 'LITERATURE, SLAVIC', 'LOGIC', 'MANAGEMENT', 'MARINE & FRESHWATER BIOLOGY', 'MATERIALS SCIENCE, BIOMATERIALS', 'MATERIALS SCIENCE, CERAMICS', 'MATERIALS SCIENCE, CHARACTERIZATION & TESTING', 'MATERIALS SCIENCE, COATINGS & FILMS', 'MATERIALS SCIENCE, COMPOSITES', 'MATERIALS SCIENCE, MULTIDISCIPLINARY', 'MATERIALS SCIENCE, PAPER & WOOD', 'MATERIALS SCIENCE, TEXTILES', 'MATHEMATICAL & COMPUTATIONAL BIOLOGY', 'MATHEMATICS', 'MATHEMATICS, APPLIED', 'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS', 'MECHANICS', 'MEDICAL ETHICS', 'MEDICAL INFORMATICS', 'MEDICAL LABORATORY TECHNOLOGY', 'MEDICINE, GENERAL & INTERNAL', 'MEDICINE,  ...
# 254

# %%
#SCIE
all_intersection = set()
for index in ['SSCI','SCIE', 'AHCI']:
    numCateCounter = Counter()
    for k,v in journal_cate.items():
        for field in v['jcrCate'].split('$'):
            # if field[:-7] == 'HISTORY & PHILOSOPHY OF SCIENCE':
            #     print(v)
            if field[-4:] == index:
                numCateCounter[field[:-7]] += 1
    temp = set(numCateCounter.keys())
    if len(all_intersection) == 0:
        all_intersection = temp
    else:
        all_intersection = all_intersection & temp
    # print(numCateCounter)
    # numIndex , frequency = zip(*sorted(numCateCounter.items()))
    # print(numIndex, frequency)
    # print(len(numIndex))
    print(len(all_intersection))
    print(all_intersection)
# Out:
# 58
# {'WOMENS STUDIES', 'SOCIAL WORK', 'URBAN STUDIES', 'EDUCATION & EDUCATIONAL RESEARCH', 'REGIONAL & URBAN PLANNING', 'PSYCHOLOGY, EXPERIMENTAL', 'SOCIOLOGY', 'MANAGEMENT', 'ERGONOMICS', 'SOCIAL SCIENCES, BIOMEDICAL', 'SUBSTANCE ABUSE', 'LAW', 'INDUSTRIAL RELATIONS & LABOR', 'DEVELOPMENT STUDIES', 'PSYCHOLOGY, MATHEMATICAL', 'TRANSPORTATION', 'PSYCHIATRY', 'ENVIRONMENTAL STUDIES', 'INTERNATIONAL RELATIONS', 'HEALTH POLICY & SERVICES', 'LINGUISTICS', 'HISTORY', 'NURSING', 'GERONTOLOGY', 'BUSINESS, FINANCE', 'SOCIAL SCIENCES, MATHEMATICAL METHODS', 'EDUCATION, SPECIAL', 'FAMILY STUDIES', 'HISTORY OF SOCIAL SCIENCES', 'PSYCHOLOGY, APPLIED', 'ETHNIC STUDIES', 'PSYCHOLOGY, BIOLOGICAL', 'INFORMATION SCIENCE & LIBRARY SCIENCE', 'ECONOMICS', 'HISTORY & PHILOSOPHY OF SCIENCE', 'SOCIAL SCIENCES, INTERDISCIPLINARY', 'CRIMINOLOGY & PENOLOGY', 'AREA STUDIES', 'PSYCHOLOGY, PSYCHOANALYSIS', 'PSYCHOLOGY, MULTIDISCIPLINARY', 'ANTHROPOLOGY', 'PSYCHOLOGY, DEVELOPMENTAL', 'GEOGRAPHY', 'PUBLIC ADMINISTRATION', 'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH', 'PSYCHOLOGY, EDUCATIONAL', 'SOCIAL ISSUES', 'REHABILITATION', 'HOSPITALITY, LEISURE, SPORT & TOURISM', 'POLITICAL SCIENCE', 'ETHICS', 'COMMUNICATION', 'PSYCHOLOGY, SOCIAL', 'PSYCHOLOGY, CLINICAL', 'BUSINESS', 'CULTURAL STUDIES', 'DEMOGRAPHY', 'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY'}
# 7
# {'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH', 'PSYCHIATRY', 'REHABILITATION', 'NURSING', 'HISTORY & PHILOSOPHY OF SCIENCE', 'SUBSTANCE ABUSE', 'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY'}
# 1
# {'HISTORY & PHILOSOPHY OF SCIENCE'}

# %% [markdown]
# 很自然, 这里得到一个简化后的期刊分类关系, 包含期刊MAG号,期刊名,期刊JCR分类(不包含所属的索引), JIF 和JCI, JCI可以看作. 以mag id 为key. 存下来,方便后续使用.
#
# {'jcrCate': 'FORESTRY - SCIE', 'jcrName': 'Austrian Journal of Forest Science', 'magName': 'austrian journal of forest science', 'magIssn': ['0379-5292', '0379-5292'], 'jcrIssn': '0379-5292', 'jcrEIssn': '0375-524X', '2021-JIF': '1.143', '2021-Qscie': 'Q4', '2021-Qssci': 'N/A', '2021-Qahci': 'N/A', '2021-JCI': '0.41'}

# %%
# #  {'Jtitle': str,'2021JIF': float, '2021JCI': float, FieldList: list, CitationIndexList: list}
# # 定义一个函数,解决 'N/A' 无法转换为float的问题.
# def str2float(s):
#     if s == 'N/A':
#         return np.nan
#     else:
#         return float(s)
# mag2journal ={}
# for k,v in journal_cate.items():
#     mag2journal[k] = {'Jtitle': v['jcrName'],'2021JIF': str2float(v['2021-JIF']), '2021JCI': str2float(v['2021-JCI']) }
#     fieldlistraw = v['jcrCate'].split('$')
#     fieldlist = []
#     for fieldraw in fieldlistraw:
#         fieldlist.append(fieldraw[:-7])
#     mag2journal[k]['FieldList'] = fieldlist
#     CitationIndexlist = []
#     for fieldraw in fieldlistraw:
#         CitationIndexlist.append(fieldraw[-4:])
#     mag2journal[k]['CitationIndexList'] = CitationIndexlist
# pk.dump(mag2journal, open('../DataCrossBoundaryPerspective_InterdisciplinaryResearch/mag2journal.pk', 'wb'))
# mag2journal

# %%
mag2journal = pk.load(open('../../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/mag2journal.pk', 'rb'))

# %%
mag2journal
# Out:
# {'176781058': {'Jtitle': 'Mathematical Population Studies',
#   '2021JIF': 1.355,
#   '2021JCI': 0.38,
#   'FieldList': ['MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#    'STATISTICS & PROBABILITY',
#    'DEMOGRAPHY',
#    'SOCIAL SCIENCES, MATHEMATICAL METHODS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']},
#  '18095265': {'Jtitle': 'Journal of Mineralogical and Petrological Sciences',
#   '2021JIF': 1.041,
#   '2021JCI': 0.3,
#   'FieldList': ['MINERALOGY'],
#   'CitationIndexList': ['SCIE']},
#  '28603624': {'Jtitle': 'STRAHLENTHERAPIE UND ONKOLOGIE',
#   '2021JIF': 4.033,
#   '2021JCI': 0.79,
#   'FieldList': ['ONCOLOGY', 'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '20253135': {'Jtitle': 'M S-MEDECINE SCIENCES',
#   '2021JIF': 0.716,
#   '2021JCI': 0.13,
#   'FieldList': ['MEDICINE, RESEARCH & EXPERIMENTAL'],
#   'CitationIndexList': ['SCIE']},
#  '37879208': {'Jtitle': 'AMERICAN JOURNAL OF SURGICAL PATHOLOGY',
#   '2021JIF': 6.298,
#   '2021JCI': 2.24,
#   'FieldList': ['PATHOLOGY', 'SURGERY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '99462834': {'Jtitle': 'HEREDITY',
#   '2021JIF': 3.832,
#   '2021JCI': 0.92,
#   'FieldList': ['ECOLOGY', 'EVOLUTIONARY BIOLOGY', 'GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '128124174': {'Jtitle': 'Cell Stem Cell',
#   '2021JIF': 25.269,
#   '2021JCI': 4.15,
#   'FieldList': ['CELL & TISSUE ENGINEERING', 'CELL BIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '103897674': {'Jtitle': 'PROTIST',
#   '2021JIF': 2.656,
#   '2021JCI': 0.56,
#   'FieldList': ['MICROBIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '98347115': {'Jtitle': 'INVENTIONES MATHEMATICAE',
#   '2021JIF': 3.128,
#   '2021JCI': 2.74,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '2480243177': {'Jtitle': 'Austrian Journal of Forest Science',
#   '2021JIF': 1.143,
#   '2021JCI': 0.41,
#   'FieldList': ['FORESTRY'],
#   'CitationIndexList': ['SCIE']},
#  '166445956': {'Jtitle': 'FERROELECTRICS LETTERS SECTION',
#   '2021JIF': 0.5,
#   '2021JCI': 0.1,
#   'FieldList': ['PHYSICS, CONDENSED MATTER'],
#   'CitationIndexList': ['SCIE']},
#  '90160718': {'Jtitle': 'JOURNAL OF GENETIC PSYCHOLOGY',
#   '2021JIF': 1.333,
#   '2021JCI': 0.43,
#   'FieldList': ['PSYCHOLOGY',
#    'PSYCHOLOGY, DEVELOPMENTAL',
#    'PSYCHOLOGY, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SSCI', 'SSCI']},
#  '31010182': {'Jtitle': 'REVIEW OF SCIENTIFIC INSTRUMENTS',
#   '2021JIF': 1.843,
#   '2021JCI': 0.4,
#   'FieldList': ['INSTRUMENTS & INSTRUMENTATION', 'PHYSICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '34872747': {'Jtitle': 'BIOTECHNOLOGY AND APPLIED BIOCHEMISTRY',
#   '2021JIF': 2.724,
#   '2021JCI': 0.47,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY',
#    'BIOTECHNOLOGY & APPLIED MICROBIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2764646616': {'Jtitle': 'ACS Infectious Diseases',
#   '2021JIF': 5.578,
#   '2021JCI': 1.25,
#   'FieldList': ['CHEMISTRY, MEDICINAL', 'INFECTIOUS DISEASES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '170502224': {'Jtitle': 'ACM Transactions on Sensor Networks',
#   '2021JIF': 2.56,
#   '2021JCI': 0.71,
#   'FieldList': ['COMPUTER SCIENCE, INFORMATION SYSTEMS', 'TELECOMMUNICATIONS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '108239708': {'Jtitle': 'INTERNATIONAL JOURNAL OF LIFE CYCLE ASSESSMENT',
#   '2021JIF': 5.257,
#   '2021JCI': 0.68,
#   'FieldList': ['ENGINEERING, ENVIRONMENTAL', 'ENVIRONMENTAL SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '13083541': {'Jtitle': 'Journal of Pediatric and Adolescent Gynecology',
#   '2021JIF': 2.046,
#   '2021JCI': 0.73,
#   'FieldList': ['OBSTETRICS & GYNECOLOGY', 'PEDIATRICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '48180145': {'Jtitle': 'JOURNAL OF MOLECULAR DIAGNOSTICS',
#   '2021JIF': 5.341,
#   '2021JCI': 1.67,
#   'FieldList': ['PATHOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '173281865': {'Jtitle': 'ACTA NEUROPSYCHIATRICA',
#   '2021JIF': 4.513,
#   '2021JCI': 0.61,
#   'FieldList': ['NEUROSCIENCES', 'PSYCHIATRY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '137552098': {'Jtitle': 'Contact Lens & Anterior Eye',
#   '2021JIF': 3.946,
#   '2021JCI': 1.28,
#   'FieldList': ['OPHTHALMOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '38341973': {'Jtitle': 'CORROSION ENGINEERING SCIENCE AND TECHNOLOGY',
#   '2021JIF': 1.971,
#   '2021JCI': 0.37,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY',
#    'METALLURGY & METALLURGICAL ENGINEERING'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '14299449': {'Jtitle': 'Gastroenterology Research and Practice',
#   '2021JIF': 1.919,
#   '2021JCI': 0.35,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '81330323': {'Jtitle': 'Endokrynologia Polska',
#   '2021JIF': 1.569,
#   '2021JCI': 0.3,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM'],
#   'CitationIndexList': ['SCIE']},
#  '13265631': {'Jtitle': 'ARCHIVES OF CLINICAL NEUROPSYCHOLOGY',
#   '2021JIF': 3.448,
#   '2021JCI': 0.96,
#   'FieldList': ['PSYCHOLOGY', 'PSYCHOLOGY, CLINICAL'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '4210217549': {'Jtitle': 'JOURNAL OF THE AMERICAN SOCIETY FOR HORTICULTURAL SCIENCE',
#   '2021JIF': 1.53,
#   '2021JCI': 0.54,
#   'FieldList': ['HORTICULTURE'],
#   'CitationIndexList': ['SCIE']},
#  '54128167': {'Jtitle': 'MEDICAL PRINCIPLES AND PRACTICE',
#   '2021JIF': 2.132,
#   '2021JCI': 0.58,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '207559368': {'Jtitle': 'JOURNAL OF ATMOSPHERIC AND SOLAR-TERRESTRIAL PHYSICS',
#   '2021JIF': 2.119,
#   '2021JCI': 0.5,
#   'FieldList': ['GEOCHEMISTRY & GEOPHYSICS',
#    'METEOROLOGY & ATMOSPHERIC SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '89339265': {'Jtitle': 'JOURNAL OF CEREBRAL BLOOD FLOW AND METABOLISM',
#   '2021JIF': 6.597,
#   '2021JCI': 1.36,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM', 'HEMATOLOGY', 'NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '193671726': {'Jtitle': 'GRASAS Y ACEITES',
#   '2021JIF': 1.416,
#   '2021JCI': 0.32,
#   'FieldList': ['CHEMISTRY, APPLIED', 'FOOD SCIENCE & TECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '117436046': {'Jtitle': 'CYBERNETICS AND SYSTEMS',
#   '2021JIF': 1.859,
#   '2021JCI': 0.29,
#   'FieldList': ['COMPUTER SCIENCE, CYBERNETICS'],
#   'CitationIndexList': ['SCIE']},
#  '56953219': {'Jtitle': 'VOX SANGUINIS',
#   '2021JIF': 2.996,
#   '2021JCI': 0.42,
#   'FieldList': ['HEMATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '89023782': {'Jtitle': 'TRENDS IN FOOD SCIENCE & TECHNOLOGY',
#   '2021JIF': 16.002,
#   '2021JCI': 1.67,
#   'FieldList': ['FOOD SCIENCE & TECHNOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '12965339': {'Jtitle': 'ACTA MATHEMATICA HUNGARICA',
#   '2021JIF': 0.979,
#   '2021JCI': 0.75,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '1244823': {'Jtitle': 'PLASMA CHEMISTRY AND PLASMA PROCESSING',
#   '2021JIF': 3.337,
#   '2021JCI': 0.75,
#   'FieldList': ['ENGINEERING, CHEMICAL',
#    'PHYSICS, APPLIED',
#    'PHYSICS, FLUIDS & PLASMAS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '34074479': {'Jtitle': 'Journal of Traditional Chinese Medicine',
#   '2021JIF': 2.547,
#   '2021JCI': 0.32,
#   'FieldList': ['INTEGRATIVE & COMPLEMENTARY MEDICINE'],
#   'CitationIndexList': ['SCIE']},
#  '171170845': {'Jtitle': 'DUKE MATHEMATICAL JOURNAL',
#   '2021JIF': 2.377,
#   '2021JCI': 1.93,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '198272637': {'Jtitle': 'JOURNAL OF CHILD AND ADOLESCENT PSYCHOPHARMACOLOGY',
#   '2021JIF': 3.031,
#   '2021JCI': 0.76,
#   'FieldList': ['PEDIATRICS', 'PHARMACOLOGY & PHARMACY', 'PSYCHIATRY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '4210227604': {'Jtitle': 'Annals of Gastroenterological Surgery',
#   '2021JIF': 3.583,
#   '2021JCI': 0.6,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '105693234': {'Jtitle': 'PROBABILITY THEORY AND RELATED FIELDS',
#   '2021JIF': 1.944,
#   '2021JCI': 0.92,
#   'FieldList': ['STATISTICS & PROBABILITY'],
#   'CitationIndexList': ['SCIE']},
#  '45406943': {'Jtitle': 'JOURNAL OF SEPARATION SCIENCE',
#   '2021JIF': 3.614,
#   '2021JCI': 0.71,
#   'FieldList': ['CHEMISTRY, ANALYTICAL'],
#   'CitationIndexList': ['SCIE']},
#  '62565178': {'Jtitle': 'NURSE EDUCATION TODAY',
#   '2021JIF': 3.906,
#   '2021JCI': 1.67,
#   'FieldList': ['EDUCATION, SCIENTIFIC DISCIPLINES', 'NURSING', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']},
#  '75756335': {'Jtitle': 'JOURNAL OF INTERVENTIONAL CARDIAC ELECTROPHYSIOLOGY',
#   '2021JIF': 1.759,
#   '2021JCI': 0.4,
#   'FieldList': ['CARDIAC & CARDIOVASCULAR SYSTEMS'],
#   'CitationIndexList': ['SCIE']},
#  '78190159': {'Jtitle': 'INTERNATIONAL JOURNAL OF NEUROSCIENCE',
#   '2021JIF': 2.59,
#   '2021JCI': 0.49,
#   'FieldList': ['NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '169946948': {'Jtitle': 'RAMANUJAN JOURNAL',
#   '2021JIF': 0.804,
#   '2021JCI': 0.81,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '207216207': {'Jtitle': 'IEEE INDUSTRY APPLICATIONS MAGAZINE',
#   '2021JIF': 0.756,
#   '2021JCI': 0.18,
#   'FieldList': ['ENGINEERING, ELECTRICAL & ELECTRONIC',
#    'ENGINEERING, INDUSTRIAL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '143352558': {'Jtitle': 'Gastroenterology',
#   '2021JIF': 33.883,
#   '2021JCI': 4.96,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '133939727': {'Jtitle': 'JOURNAL OF MOLECULAR NEUROSCIENCE',
#   '2021JIF': 2.866,
#   '2021JCI': 0.59,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY', 'NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2764768178': {'Jtitle': 'Journal of Oral & Facial Pain and Headache',
#   '2021JIF': 2.457,
#   '2021JCI': 0.87,
#   'FieldList': ['DENTISTRY, ORAL SURGERY & MEDICINE'],
#   'CitationIndexList': ['SCIE']},
#  '95174952': {'Jtitle': 'Animal Production Science',
#   '2021JIF': 1.57,
#   '2021JCI': 0.73,
#   'FieldList': ['AGRICULTURE, DAIRY & ANIMAL SCIENCE'],
#   'CitationIndexList': ['SCIE']},
#  '2737379694': {'Jtitle': 'Veterinary Sciences',
#   '2021JIF': 2.518,
#   '2021JCI': 1.03,
#   'FieldList': ['VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '4210195120': {'Jtitle': 'BRITISH JOURNAL OF HOSPITAL MEDICINE',
#   '2021JIF': 1.286,
#   '2021JCI': 0.19,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '20605092': {'Jtitle': 'AIDS',
#   '2021JIF': 4.632,
#   '2021JCI': 0.83,
#   'FieldList': ['IMMUNOLOGY', 'INFECTIOUS DISEASES', 'VIROLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '27897580': {'Jtitle': 'TERAPEVTICHESKII ARKHIV',
#   '2021JIF': 0.45,
#   '2021JCI': 0.09,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '90653425': {'Jtitle': 'Magnetic Resonance in Medical Sciences',
#   '2021JIF': 2.76,
#   '2021JCI': 0.69,
#   'FieldList': ['RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'],
#   'CitationIndexList': ['SCIE']},
#  '131102849': {'Jtitle': 'Journal of Oncology Practice',
#   '2021JIF': 3.714,
#   '2021JCI': 0.57,
#   'FieldList': ['ONCOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '57989705': {'Jtitle': 'AMERICAN JOURNAL OF MANAGED CARE',
#   '2021JIF': 3.247,
#   '2021JCI': 0.66,
#   'FieldList': ['HEALTH CARE SCIENCES & SERVICES',
#    'MEDICINE, GENERAL & INTERNAL',
#    'HEALTH POLICY & SERVICES'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']},
#  '93354060': {'Jtitle': 'AUSTRALIAN VETERINARY JOURNAL',
#   '2021JIF': 1.343,
#   '2021JCI': 0.69,
#   'FieldList': ['VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '162601632': {'Jtitle': 'HIGH TEMPERATURE',
#   '2021JIF': 0.518,
#   '2021JCI': 0.16,
#   'FieldList': ['PHYSICS, APPLIED'],
#   'CitationIndexList': ['SCIE']},
#  '191726168': {'Jtitle': 'JOURNAL OF DENTISTRY',
#   '2021JIF': 4.991,
#   '2021JCI': 1.71,
#   'FieldList': ['DENTISTRY, ORAL SURGERY & MEDICINE'],
#   'CitationIndexList': ['SCIE']},
#  '157344032': {'Jtitle': 'JOURNAL OF PHYSICAL ORGANIC CHEMISTRY',
#   '2021JIF': 2.155,
#   '2021JCI': 0.42,
#   'FieldList': ['CHEMISTRY, ORGANIC', 'CHEMISTRY, PHYSICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '26596028': {'Jtitle': 'ENTOMOLOGIA EXPERIMENTALIS ET APPLICATA',
#   '2021JIF': 2.433,
#   '2021JCI': 0.87,
#   'FieldList': ['ENTOMOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '58475062': {'Jtitle': 'Physical Mesomechanics',
#   '2021JIF': 2.025,
#   '2021JCI': 0.66,
#   'FieldList': ['MATERIALS SCIENCE, CHARACTERIZATION & TESTING', 'MECHANICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '4210217375': {'Jtitle': 'Annual Review of Statistics and Its Application',
#   '2021JIF': 7.917,
#   '2021JCI': 0.66,
#   'FieldList': ['MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#    'STATISTICS & PROBABILITY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '198828251': {'Jtitle': 'Evolutionary Biology',
#   '2021JIF': 3.696,
#   '2021JCI': 0.67,
#   'FieldList': ['EVOLUTIONARY BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '90605627': {'Jtitle': 'JOURNAL OF ENDODONTICS',
#   '2021JIF': 4.422,
#   '2021JCI': 1.77,
#   'FieldList': ['DENTISTRY, ORAL SURGERY & MEDICINE'],
#   'CitationIndexList': ['SCIE']},
#  '152840809': {'Jtitle': 'CHEMICAL RESEARCH IN TOXICOLOGY',
#   '2021JIF': 3.973,
#   '2021JCI': 0.85,
#   'FieldList': ['CHEMISTRY, MEDICINAL',
#    'CHEMISTRY, MULTIDISCIPLINARY',
#    'TOXICOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '47042973': {'Jtitle': 'CAMBRIDGE QUARTERLY OF HEALTHCARE ETHICS',
#   '2021JIF': 1.566,
#   '2021JCI': 0.47,
#   'FieldList': ['HEALTH CARE SCIENCES & SERVICES',
#    'HEALTH POLICY & SERVICES',
#    'SOCIAL SCIENCES, BIOMEDICAL'],
#   'CitationIndexList': ['SCIE', 'SSCI', 'SSCI']},
#  '182284546': {'Jtitle': 'MOLECULAR VISION',
#   '2021JIF': 2.711,
#   '2021JCI': 0.67,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY', 'OPHTHALMOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '52251279': {'Jtitle': 'POTATO RESEARCH',
#   '2021JIF': 2.561,
#   '2021JCI': 0.75,
#   'FieldList': ['AGRONOMY'],
#   'CitationIndexList': ['SCIE']},
#  '2764691743': {'Jtitle': 'Journal of Pediatric Infectious Diseases',
#   '2021JIF': 0.374,
#   '2021JCI': 0.11,
#   'FieldList': ['INFECTIOUS DISEASES', 'PEDIATRICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '134406477': {'Jtitle': 'HEALTH EXPECTATIONS',
#   '2021JIF': 3.318,
#   '2021JCI': 0.91,
#   'FieldList': ['HEALTH CARE SCIENCES & SERVICES',
#    'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#    'HEALTH POLICY & SERVICES',
#    'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']},
#  '2486144580': {'Jtitle': 'MRS Communications',
#   '2021JIF': 2.935,
#   '2021JCI': 0.42,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '9986330': {'Jtitle': 'Breast Care',
#   '2021JIF': 2.268,
#   '2021JCI': 0.54,
#   'FieldList': ['OBSTETRICS & GYNECOLOGY', 'ONCOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '166852190': {'Jtitle': 'Polymer Reviews',
#   '2021JIF': 14.536,
#   '2021JCI': 0.94,
#   'FieldList': ['POLYMER SCIENCE'],
#   'CitationIndexList': ['SCIE']},
#  '55147621': {'Jtitle': 'Molecular Imaging',
#   '2021JIF': 3.25,
#   '2021JCI': 0.7,
#   'FieldList': ['BIOCHEMICAL RESEARCH METHODS',
#    'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '181332294': {'Jtitle': 'PHYSICAL CHEMISTRY CHEMICAL PHYSICS',
#   '2021JIF': 3.945,
#   '2021JCI': 0.78,
#   'FieldList': ['CHEMISTRY, PHYSICAL',
#    'PHYSICS, ATOMIC, MOLECULAR & CHEMICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2764668616': {'Jtitle': 'Journal of Mathematics',
#   '2021JIF': 1.555,
#   '2021JCI': 1.01,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '4210185107': {'Jtitle': 'Communications in Mathematics and Statistics',
#   '2021JIF': 0.868,
#   '2021JCI': 1.13,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '156255550': {'Jtitle': 'ADVANCED ENGINEERING MATERIALS',
#   '2021JIF': 4.122,
#   '2021JCI': 0.51,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '4210210487': {'Jtitle': 'Trends in Chemistry',
#   '2021JIF': 22.448,
#   '2021JCI': 1.42,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '64770346': {'Jtitle': 'IEEE TRANSACTIONS ON ENERGY CONVERSION',
#   '2021JIF': 4.877,
#   '2021JCI': 1.02,
#   'FieldList': ['ENERGY & FUELS', 'ENGINEERING, ELECTRICAL & ELECTRONIC'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2477089890': {'Jtitle': 'Rural and Remote Health',
#   '2021JIF': 2.733,
#   '2021JCI': 0.43,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#    'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '38880878': {'Jtitle': 'AUSTRAL ECOLOGY',
#   '2021JIF': 1.771,
#   '2021JCI': 0.48,
#   'FieldList': ['ECOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '6997661': {'Jtitle': 'SEMINARS IN NUCLEAR MEDICINE',
#   '2021JIF': 4.802,
#   '2021JCI': 0.94,
#   'FieldList': ['RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'],
#   'CitationIndexList': ['SCIE']},
#  '178451187': {'Jtitle': 'NORDIC JOURNAL OF BOTANY',
#   '2021JIF': 0.931,
#   '2021JCI': 0.24,
#   'FieldList': ['PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '2500128275': {'Jtitle': 'Journal of Energy Chemistry',
#   '2021JIF': 13.599,
#   '2021JCI': 1.81,
#   'FieldList': ['CHEMISTRY, APPLIED',
#    'CHEMISTRY, PHYSICAL',
#    'ENERGY & FUELS',
#    'ENGINEERING, CHEMICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '58085280': {'Jtitle': 'BIPOLAR DISORDERS',
#   '2021JIF': 5.345,
#   '2021JCI': 1.11,
#   'FieldList': ['CLINICAL NEUROLOGY', 'NEUROSCIENCES', 'PSYCHIATRY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '6525137': {'Jtitle': 'CURRENT NEUROVASCULAR RESEARCH',
#   '2021JIF': 2.294,
#   '2021JCI': 0.5,
#   'FieldList': ['CLINICAL NEUROLOGY', 'NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '170491511': {'Jtitle': 'Bulletin of the Polish Academy of Sciences-Technical Sciences',
#   '2021JIF': 1.515,
#   '2021JCI': 0.54,
#   'FieldList': ['ENGINEERING, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '73435037': {'Jtitle': 'PROGRES EN UROLOGIE',
#   '2021JIF': 1.09,
#   '2021JCI': 0.3,
#   'FieldList': ['UROLOGY & NEPHROLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '4210204015': {'Jtitle': 'JOURNAL OF GEODESY',
#   '2021JIF': 4.809,
#   '2021JCI': 1.18,
#   'FieldList': ['GEOCHEMISTRY & GEOPHYSICS', 'REMOTE SENSING'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '97146013': {'Jtitle': 'DNA AND CELL BIOLOGY',
#   '2021JIF': 3.55,
#   '2021JCI': 0.59,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY',
#    'CELL BIOLOGY',
#    'GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '124948411': {'Jtitle': 'CLINICAL CHEMISTRY AND LABORATORY MEDICINE',
#   '2021JIF': 8.49,
#   '2021JCI': 1.85,
#   'FieldList': ['MEDICAL LABORATORY TECHNOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '4210193854': {'Jtitle': 'DEUTSCHE ENTOMOLOGISCHE ZEITSCHRIFT',
#   '2021JIF': 1.174,
#   '2021JCI': 0.53,
#   'FieldList': ['ENTOMOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '200472310': {'Jtitle': 'CRYPTOGAMIE BRYOLOGIE',
#   '2021JIF': 1.341,
#   '2021JCI': 0.28,
#   'FieldList': ['PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '61378919': {'Jtitle': 'KLINISCHE MONATSBLATTER FUR AUGENHEILKUNDE',
#   '2021JIF': 0.742,
#   '2021JCI': 0.27,
#   'FieldList': ['OPHTHALMOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '95928045': {'Jtitle': 'Laser & Photonics Reviews',
#   '2021JIF': 10.947,
#   '2021JCI': 2.05,
#   'FieldList': ['OPTICS', 'PHYSICS, APPLIED', 'PHYSICS, CONDENSED MATTER'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '98049309': {'Jtitle': 'Zoologia',
#   '2021JIF': 0.859,
#   '2021JCI': 0.44,
#   'FieldList': ['ZOOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '149215848': {'Jtitle': 'Neurosurgical Focus',
#   '2021JIF': 4.332,
#   '2021JCI': 1.23,
#   'FieldList': ['CLINICAL NEUROLOGY', 'SURGERY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '133795288': {'Jtitle': 'IEEE Transactions on Dependable and Secure Computing',
#   '2021JIF': 6.791,
#   '2021JCI': 2.25,
#   'FieldList': ['COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#    'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#    'COMPUTER SCIENCE, SOFTWARE ENGINEERING'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '181994529': {'Jtitle': 'Journal of Diabetes',
#   '2021JIF': 4.545,
#   '2021JCI': 0.72,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM'],
#   'CitationIndexList': ['SCIE']},
#  '185969502': {'Jtitle': 'JOURNAL OF AGRICULTURAL BIOLOGICAL AND ENVIRONMENTAL STATISTICS',
#   '2021JIF': 2.267,
#   '2021JCI': 0.6,
#   'FieldList': ['BIOLOGY',
#    'MATHEMATICAL & COMPUTATIONAL BIOLOGY',
#    'STATISTICS & PROBABILITY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '63111534': {'Jtitle': 'NORDIC JOURNAL OF PSYCHIATRY',
#   '2021JIF': 2.099,
#   '2021JCI': 0.47,
#   'FieldList': ['PSYCHIATRY', 'PSYCHIATRY'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '207341031': {'Jtitle': 'Progress in Physical Geography-Earth and Environment',
#   '2021JIF': 4.283,
#   '2021JCI': 0.91,
#   'FieldList': ['GEOGRAPHY, PHYSICAL', 'GEOSCIENCES, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '143717524': {'Jtitle': 'International Journal of Fruit Science',
#   '2021JIF': 1.534,
#   '2021JCI': 0.5,
#   'FieldList': ['HORTICULTURE'],
#   'CitationIndexList': ['SCIE']},
#  '2738600312': {'Jtitle': 'npj Quantum Information',
#   '2021JIF': 10.758,
#   '2021JCI': 2.21,
#   'FieldList': ['PHYSICS, APPLIED',
#    'PHYSICS, ATOMIC, MOLECULAR & CHEMICAL',
#    'PHYSICS, CONDENSED MATTER',
#    'QUANTUM SCIENCE & TECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '104737098': {'Jtitle': 'ADVANCES IN STRUCTURAL ENGINEERING',
#   '2021JIF': 2.438,
#   '2021JCI': 0.44,
#   'FieldList': ['CONSTRUCTION & BUILDING TECHNOLOGY', 'ENGINEERING, CIVIL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2764830028': {'Jtitle': 'Dermatology Practical & Conceptual',
#   '2021JIF': 2.753,
#   '2021JCI': 0.6,
#   'FieldList': ['DERMATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '28612791': {'Jtitle': 'International Journal of Health Geographics',
#   '2021JIF': 5.31,
#   '2021JCI': 1.04,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#    'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '143381477': {'Jtitle': 'ENVIRONMENT INTERNATIONAL',
#   '2021JIF': 13.352,
#   '2021JCI': 1.93,
#   'FieldList': ['ENVIRONMENTAL SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '200673814': {'Jtitle': 'Veterinary and Comparative Oncology',
#   '2021JIF': 2.385,
#   '2021JCI': 1.14,
#   'FieldList': ['VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '4210213780': {'Jtitle': 'Inra Productions Animales',
#   '2021JIF': 0.904,
#   '2021JCI': 0.41,
#   'FieldList': ['AGRICULTURE, DAIRY & ANIMAL SCIENCE', 'VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '487226': {'Jtitle': 'Condensed Matter Physics',
#   '2021JIF': 0.75,
#   '2021JCI': 0.15,
#   'FieldList': ['PHYSICS, CONDENSED MATTER'],
#   'CitationIndexList': ['SCIE']},
#  '45405298': {'Jtitle': 'ACTA ORNITHOLOGICA',
#   '2021JIF': 0.83,
#   '2021JCI': 0.68,
#   'FieldList': ['ORNITHOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '11990909': {'Jtitle': 'INTERNATIONAL FORESTRY REVIEW',
#   '2021JIF': 1.369,
#   '2021JCI': 0.58,
#   'FieldList': ['FORESTRY'],
#   'CitationIndexList': ['SCIE']},
#  '10731693': {'Jtitle': 'IEEJ Transactions on Electrical and Electronic Engineering',
#   '2021JIF': 0.923,
#   '2021JCI': 0.22,
#   'FieldList': ['ENGINEERING, ELECTRICAL & ELECTRONIC'],
#   'CitationIndexList': ['SCIE']},
#  '85837164': {'Jtitle': 'CANADIAN JOURNAL OF REMOTE SENSING',
#   '2021JIF': 2.242,
#   '2021JCI': 0.43,
#   'FieldList': ['REMOTE SENSING'],
#   'CitationIndexList': ['SCIE']},
#  '4210187659': {'Jtitle': 'SURGICAL LAPAROSCOPY ENDOSCOPY & PERCUTANEOUS TECHNIQUES',
#   '2021JIF': 1.455,
#   '2021JCI': 0.54,
#   'FieldList': ['SURGERY'],
#   'CitationIndexList': ['SCIE']},
#  '135472351': {'Jtitle': 'EUROPEAN POLYMER JOURNAL',
#   '2021JIF': 5.546,
#   '2021JCI': 1.05,
#   'FieldList': ['POLYMER SCIENCE'],
#   'CitationIndexList': ['SCIE']},
#  '22216944': {'Jtitle': 'IRRIGATION AND DRAINAGE',
#   '2021JIF': 1.424,
#   '2021JCI': 0.4,
#   'FieldList': ['AGRONOMY', 'WATER RESOURCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '194302669': {'Jtitle': 'JOURNAL OF PAIN',
#   '2021JIF': 5.383,
#   '2021JCI': 1.16,
#   'FieldList': ['CLINICAL NEUROLOGY', 'NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '75627607': {'Jtitle': 'PSYCHOLOGICAL BULLETIN',
#   '2021JIF': 23.027,
#   '2021JCI': 5.54,
#   'FieldList': ['PSYCHOLOGY', 'PSYCHOLOGY, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '4210221166': {'Jtitle': 'Sugar Industry-Zuckerindustrie',
#   '2021JIF': 0.663,
#   '2021JCI': 0.14,
#   'FieldList': ['FOOD SCIENCE & TECHNOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '71689831': {'Jtitle': 'PHYSICA STATUS SOLIDI B-BASIC SOLID STATE PHYSICS',
#   '2021JIF': 1.782,
#   '2021JCI': 0.29,
#   'FieldList': ['PHYSICS, CONDENSED MATTER'],
#   'CitationIndexList': ['SCIE']},
#  '196760182': {'Jtitle': 'Tropical Plant Pathology',
#   '2021JIF': 2.404,
#   '2021JCI': 0.45,
#   'FieldList': ['PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '56946555': {'Jtitle': 'Journal of Biopharmaceutical Statistics',
#   '2021JIF': 1.503,
#   '2021JCI': 0.44,
#   'FieldList': ['PHARMACOLOGY & PHARMACY', 'STATISTICS & PROBABILITY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '11742566': {'Jtitle': 'MOLECULAR AND CELLULAR BIOCHEMISTRY',
#   '2021JIF': 3.842,
#   '2021JCI': 0.5,
#   'FieldList': ['CELL BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '3880285': {'Jtitle': 'SCIENCE',
#   '2021JIF': 63.832,
#   '2021JCI': 10.15,
#   'FieldList': ['MULTIDISCIPLINARY SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '120990105': {'Jtitle': 'JOURNAL OF THE MATHEMATICAL SOCIETY OF JAPAN',
#   '2021JIF': 0.771,
#   '2021JCI': 0.71,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '2595389538': {'Jtitle': 'Frontiers in Materials',
#   '2021JIF': 3.985,
#   '2021JCI': 0.46,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '139950591': {'Jtitle': 'AGRONOMY JOURNAL',
#   '2021JIF': 2.65,
#   '2021JCI': 0.86,
#   'FieldList': ['AGRONOMY'],
#   'CitationIndexList': ['SCIE']},
#  '66095140': {'Jtitle': 'Jornal de Pediatria',
#   '2021JIF': 2.99,
#   '2021JCI': 1.75,
#   'FieldList': ['PEDIATRICS'],
#   'CitationIndexList': ['SCIE']},
#  '162176842': {'Jtitle': 'Biomedical Engineering Online',
#   '2021JIF': 3.903,
#   '2021JCI': 0.62,
#   'FieldList': ['ENGINEERING, BIOMEDICAL'],
#   'CitationIndexList': ['SCIE']},
#  '177107850': {'Jtitle': 'GASTROENTEROLOGY CLINICS OF NORTH AMERICA',
#   '2021JIF': 3.867,
#   '2021JCI': 0.74,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '2754843627': {'Jtitle': 'Cancer Medicine',
#   '2021JIF': 4.711,
#   '2021JCI': 0.82,
#   'FieldList': ['ONCOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '2764732809': {'Jtitle': 'Journal of Clinical and Translational Hepatology',
#   '2021JIF': 5.065,
#   '2021JCI': 0.81,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '16535137': {'Jtitle': 'Diabetes Therapy',
#   '2021JIF': 3.605,
#   '2021JCI': 0.66,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM'],
#   'CitationIndexList': ['SCIE']},
#  '175814247': {'Jtitle': 'JOURNAL OF NEUROLOGY',
#   '2021JIF': 6.682,
#   '2021JCI': 1.3,
#   'FieldList': ['CLINICAL NEUROLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '4210184765': {'Jtitle': 'Italian Journal of Geosciences',
#   '2021JIF': 1.825,
#   '2021JCI': 0.66,
#   'FieldList': ['GEOSCIENCES, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '48854176': {'Jtitle': 'Journal of Child Health Care',
#   '2021JIF': 1.896,
#   '2021JCI': 0.78,
#   'FieldList': ['NURSING', 'PEDIATRICS', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']},
#  '2737737698': {'Jtitle': 'Advanced Science',
#   '2021JIF': 17.521,
#   '2021JCI': 2.23,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY',
#    'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#    'NANOSCIENCE & NANOTECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '50379844': {'Jtitle': 'MATERIALES DE CONSTRUCCION',
#   '2021JIF': 2.133,
#   '2021JCI': 0.38,
#   'FieldList': ['CONSTRUCTION & BUILDING TECHNOLOGY',
#    'MATERIALS SCIENCE, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '77764115': {'Jtitle': 'Studies in History and Philosophy of Science Part C-Studies in History and Philosophy of Biological and Biomedical Sciences',
#   '2021JIF': 0.964,
#   '2021JCI': 0.66,
#   'FieldList': ['HISTORY & PHILOSOPHY OF SCIENCE',
#    'HISTORY & PHILOSOPHY OF SCIENCE',
#    'HISTORY & PHILOSOPHY OF SCIENCE'],
#   'CitationIndexList': ['SCIE', 'AHCI', 'SSCI']},
#  '149644738': {'Jtitle': 'GENE EXPRESSION PATTERNS',
#   '2021JIF': 1.488,
#   '2021JCI': 0.33,
#   'FieldList': ['DEVELOPMENTAL BIOLOGY', 'GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '123979729': {'Jtitle': 'BIOMEDICAL CHROMATOGRAPHY',
#   '2021JIF': 1.911,
#   '2021JCI': 0.41,
#   'FieldList': ['BIOCHEMICAL RESEARCH METHODS',
#    'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#    'CHEMISTRY, ANALYTICAL',
#    'PHARMACOLOGY & PHARMACY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '2495239260': {'Jtitle': 'Journal of Ovonic Research',
#   '2021JIF': 0.892,
#   '2021JCI': 0.2,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY', 'PHYSICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '4210208160': {'Jtitle': 'Adipocyte',
#   '2021JIF': 3.553,
#   '2021JCI': 0.63,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM'],
#   'CitationIndexList': ['SCIE']},
#  '150433807': {'Jtitle': 'JOURNAL OF NUTRITIONAL SCIENCE AND VITAMINOLOGY',
#   '2021JIF': 2.032,
#   '2021JCI': 0.3,
#   'FieldList': ['NUTRITION & DIETETICS'],
#   'CitationIndexList': ['SCIE']},
#  '165401249': {'Jtitle': 'JOURNAL OF THEORETICAL & COMPUTATIONAL CHEMISTRY',
#   '2021JIF': 2.44,
#   '2021JCI': 0.28,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '21344893': {'Jtitle': 'PLASTICS RUBBER AND COMPOSITES',
#   '2021JIF': 1.843,
#   '2021JCI': 0.37,
#   'FieldList': ['MATERIALS SCIENCE, COMPOSITES', 'POLYMER SCIENCE'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '166870025': {'Jtitle': 'ECOLOGICAL APPLICATIONS',
#   '2021JIF': 6.105,
#   '2021JCI': 1.14,
#   'FieldList': ['ECOLOGY', 'ENVIRONMENTAL SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '169822654': {'Jtitle': 'INTERNATIONAL JOURNAL OF ONCOLOGY',
#   '2021JIF': 5.884,
#   '2021JCI': 1.01,
#   'FieldList': ['ONCOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '147026946': {'Jtitle': 'SAMJ SOUTH AFRICAN MEDICAL JOURNAL',
#   '2021JIF': 2.162,
#   '2021JCI': 0.38,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '88565281': {'Jtitle': 'CHINESE JOURNAL OF ANALYTICAL CHEMISTRY',
#   '2021JIF': 1.193,
#   '2021JCI': 0.24,
#   'FieldList': ['CHEMISTRY, ANALYTICAL'],
#   'CitationIndexList': ['SCIE']},
#  '19081469': {'Jtitle': 'Tissue Engineering Part A',
#   '2021JIF': 4.08,
#   '2021JCI': 0.71,
#   'FieldList': ['CELL & TISSUE ENGINEERING',
#    'CELL BIOLOGY',
#    'ENGINEERING, BIOMEDICAL',
#    'MATERIALS SCIENCE, BIOMATERIALS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '134678447': {'Jtitle': 'Environmental Chemistry',
#   '2021JIF': 4.236,
#   '2021JCI': 0.51,
#   'FieldList': ['CHEMISTRY, ANALYTICAL', 'ENVIRONMENTAL SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '161053114': {'Jtitle': 'Central European Journal of Operations Research',
#   '2021JIF': 2.407,
#   '2021JCI': 0.61,
#   'FieldList': ['OPERATIONS RESEARCH & MANAGEMENT SCIENCE'],
#   'CitationIndexList': ['SCIE']},
#  '98855836': {'Jtitle': 'IEEE Vehicular Technology Magazine',
#   '2021JIF': 13.609,
#   '2021JCI': 2.71,
#   'FieldList': ['ENGINEERING, ELECTRICAL & ELECTRONIC',
#    'TELECOMMUNICATIONS',
#    'TRANSPORTATION SCIENCE & TECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '81371064': {'Jtitle': 'ZHURNAL OBSHCHEI BIOLOGII',
#   '2021JIF': 0.306,
#   '2021JCI': 0.13,
#   'FieldList': ['BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '123199335': {'Jtitle': 'International Journal of General Medicine',
#   '2021JIF': 2.145,
#   '2021JCI': 0.46,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '149675510': {'Jtitle': 'PHYTOPROTECTION',
#   '2021JIF': 0.364,
#   '2021JCI': 0.09,
#   'FieldList': ['PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '109822313': {'Jtitle': 'G3-Genes Genomes Genetics',
#   '2021JIF': 3.542,
#   '2021JCI': 0.8,
#   'FieldList': ['GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE']},
#  '66208518': {'Jtitle': 'International Journal of Laboratory Hematology',
#   '2021JIF': 3.453,
#   '2021JCI': 0.49,
#   'FieldList': ['HEMATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '170546617': {'Jtitle': 'COMPTES RENDUS PALEVOL',
#   '2021JIF': 2.326,
#   '2021JCI': 0.86,
#   'FieldList': ['PALEONTOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '184889556': {'Jtitle': 'CLINICAL PHYSIOLOGY AND FUNCTIONAL IMAGING',
#   '2021JIF': 2.121,
#   '2021JCI': 0.56,
#   'FieldList': ['PHYSIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '2596909297': {'Jtitle': 'Frontiers in Nutrition',
#   '2021JIF': 6.59,
#   '2021JCI': 0.97,
#   'FieldList': ['NUTRITION & DIETETICS'],
#   'CitationIndexList': ['SCIE']},
#  '2502518375': {'Jtitle': 'Journal of Soil Science and Plant Nutrition',
#   '2021JIF': 3.6,
#   '2021JCI': 0.83,
#   'FieldList': ['ENVIRONMENTAL SCIENCES', 'PLANT SCIENCES', 'SOIL SCIENCE'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '143937555': {'Jtitle': 'INTERNATIONAL DENTAL JOURNAL',
#   '2021JIF': 2.607,
#   '2021JCI': 0.9,
#   'FieldList': ['DENTISTRY, ORAL SURGERY & MEDICINE'],
#   'CitationIndexList': ['SCIE']},
#  '4210173306': {'Jtitle': 'SURGERY',
#   '2021JIF': 4.348,
#   '2021JCI': 1.49,
#   'FieldList': ['SURGERY'],
#   'CitationIndexList': ['SCIE']},
#  '4210179974': {'Jtitle': 'Endocrine Metabolic & Immune Disorders-Drug Targets',
#   '2021JIF': 2.387,
#   '2021JCI': 0.47,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM',
#    'IMMUNOLOGY',
#    'PHARMACOLOGY & PHARMACY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '132957497': {'Jtitle': 'IEEE JOURNAL OF OCEANIC ENGINEERING',
#   '2021JIF': 3.883,
#   '2021JCI': 1.29,
#   'FieldList': ['ENGINEERING, CIVIL',
#    'ENGINEERING, ELECTRICAL & ELECTRONIC',
#    'ENGINEERING, OCEAN',
#    'OCEANOGRAPHY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '4210230070': {'Jtitle': 'Journal of Function Spaces',
#   '2021JIF': 1.281,
#   '2021JCI': 1.19,
#   'FieldList': ['MATHEMATICS', 'MATHEMATICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '107923245': {'Jtitle': 'COMPUTING IN SCIENCE & ENGINEERING',
#   '2021JIF': 2.152,
#   '2021JCI': 0.4,
#   'FieldList': ['COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS'],
#   'CitationIndexList': ['SCIE']},
#  '59432305': {'Jtitle': 'Journal of Building Performance Simulation',
#   '2021JIF': 2.867,
#   '2021JCI': 0.66,
#   'FieldList': ['CONSTRUCTION & BUILDING TECHNOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '124451323': {'Jtitle': 'REVUE NEUROLOGIQUE',
#   '2021JIF': 4.313,
#   '2021JCI': 0.59,
#   'FieldList': ['CLINICAL NEUROLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '199863227': {'Jtitle': 'SCANDINAVIAN JOURNAL OF MEDICINE & SCIENCE IN SPORTS',
#   '2021JIF': 4.645,
#   '2021JCI': 1.34,
#   'FieldList': ['SPORT SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '166796225': {'Jtitle': 'JOURNAL OF PHARMACY AND PHARMACEUTICAL SCIENCES',
#   '2021JIF': 3.337,
#   '2021JCI': 0.65,
#   'FieldList': ['PHARMACOLOGY & PHARMACY'],
#   'CitationIndexList': ['SCIE']},
#  '114484406': {'Jtitle': 'JOURNAL OF SYNCHROTRON RADIATION',
#   '2021JIF': 2.557,
#   '2021JCI': 0.74,
#   'FieldList': ['INSTRUMENTS & INSTRUMENTATION', 'OPTICS', 'PHYSICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '11622463': {'Jtitle': 'JOURNAL OF BIOMEDICAL INFORMATICS',
#   '2021JIF': 8.0,
#   '2021JCI': 1.22,
#   'FieldList': ['COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#    'MEDICAL INFORMATICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '132356188': {'Jtitle': 'JOURNAL OF CARDIOTHORACIC AND VASCULAR ANESTHESIA',
#   '2021JIF': 2.894,
#   '2021JCI': 0.62,
#   'FieldList': ['ANESTHESIOLOGY',
#    'CARDIAC & CARDIOVASCULAR SYSTEMS',
#    'PERIPHERAL VASCULAR DISEASE',
#    'RESPIRATORY SYSTEM'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '2063198': {'Jtitle': 'SCANDINAVIAN JOURNAL OF LABORATORY ANIMAL SCIENCE',
#   '2021JIF': 0.2,
#   '2021JCI': 0.18,
#   'FieldList': ['VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '2228914': {'Jtitle': 'HEALTH SERVICES RESEARCH',
#   '2021JIF': 3.734,
#   '2021JCI': 1.11,
#   'FieldList': ['HEALTH CARE SCIENCES & SERVICES', 'HEALTH POLICY & SERVICES'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '4210191493': {'Jtitle': 'ACS Applied Nano Materials',
#   '2021JIF': 6.14,
#   '2021JCI': 0.85,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY',
#    'NANOSCIENCE & NANOTECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '174790897': {'Jtitle': 'NEUROCHEMICAL RESEARCH',
#   '2021JIF': 4.414,
#   '2021JCI': 0.8,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY', 'NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '68913162': {'Jtitle': 'JOURNAL OF INFORMATION SCIENCE',
#   '2021JIF': 2.462,
#   '2021JCI': 0.81,
#   'FieldList': ['COMPUTER SCIENCE, INFORMATION SYSTEMS',
#    'INFORMATION SCIENCE & LIBRARY SCIENCE'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '69602258': {'Jtitle': 'Fixed Point Theory',
#   '2021JIF': 1.396,
#   '2021JCI': 1.37,
#   'FieldList': ['MATHEMATICS', 'MATHEMATICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '78419349': {'Jtitle': 'COLORATION TECHNOLOGY',
#   '2021JIF': 2.049,
#   '2021JCI': 0.39,
#   'FieldList': ['CHEMISTRY, APPLIED',
#    'ENGINEERING, CHEMICAL',
#    'MATERIALS SCIENCE, TEXTILES'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '161551636': {'Jtitle': 'WASTE MANAGEMENT & RESEARCH',
#   '2021JIF': 4.432,
#   '2021JCI': 0.47,
#   'FieldList': ['ENGINEERING, ENVIRONMENTAL', 'ENVIRONMENTAL SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '61994691': {'Jtitle': 'Cancer Biomarkers',
#   '2021JIF': 3.828,
#   '2021JCI': 0.79,
#   'FieldList': ['ONCOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '200539529': {'Jtitle': 'EUROPEAN BIOPHYSICS JOURNAL WITH BIOPHYSICS LETTERS',
#   '2021JIF': 2.095,
#   '2021JCI': 0.44,
#   'FieldList': ['BIOPHYSICS'],
#   'CitationIndexList': ['SCIE']},
#  '106004775': {'Jtitle': 'Geocarto International',
#   '2021JIF': 3.45,
#   '2021JCI': 0.79,
#   'FieldList': ['ENVIRONMENTAL SCIENCES',
#    'GEOSCIENCES, MULTIDISCIPLINARY',
#    'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#    'REMOTE SENSING'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '107049385': {'Jtitle': 'BRITISH JOURNAL FOR THE PHILOSOPHY OF SCIENCE',
#   '2021JIF': 3.282,
#   '2021JCI': 2.76,
#   'FieldList': ['HISTORY & PHILOSOPHY OF SCIENCE',
#    'HISTORY & PHILOSOPHY OF SCIENCE',
#    'HISTORY & PHILOSOPHY OF SCIENCE'],
#   'CitationIndexList': ['SCIE', 'AHCI', 'SSCI']},
#  '10542796': {'Jtitle': 'EUROPEAN JOURNAL OF CARDIO-THORACIC SURGERY',
#   '2021JIF': 4.534,
#   '2021JCI': 1.19,
#   'FieldList': ['CARDIAC & CARDIOVASCULAR SYSTEMS',
#    'RESPIRATORY SYSTEM',
#    'SURGERY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '133112271': {'Jtitle': 'International Journal of Circumpolar Health',
#   '2021JIF': 1.941,
#   '2021JCI': 0.45,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#    'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '63395545': {'Jtitle': 'BIOPHYSICAL CHEMISTRY',
#   '2021JIF': 3.628,
#   '2021JCI': 0.57,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY',
#    'BIOPHYSICS',
#    'CHEMISTRY, PHYSICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '138391592': {'Jtitle': 'Therapeutic Advances in Musculoskeletal Disease',
#   '2021JIF': 3.625,
#   '2021JCI': 0.65,
#   'FieldList': ['RHEUMATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '79332557': {'Jtitle': 'Stahlbau',
#   '2021JIF': 0.546,
#   '2021JCI': 0.12,
#   'FieldList': ['CONSTRUCTION & BUILDING TECHNOLOGY', 'ENGINEERING, CIVIL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '125705681': {'Jtitle': 'Journal of Natural Gas Science and Engineering',
#   '2021JIF': 5.285,
#   '2021JCI': 0.74,
#   'FieldList': ['ENERGY & FUELS', 'ENGINEERING, CHEMICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '155604799': {'Jtitle': 'International Breastfeeding Journal',
#   '2021JIF': 3.79,
#   '2021JCI': 1.22,
#   'FieldList': ['OBSTETRICS & GYNECOLOGY', 'PEDIATRICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '33418846': {'Jtitle': 'BRITISH JOURNAL OF ANAESTHESIA',
#   '2021JIF': 11.719,
#   '2021JCI': 2.63,
#   'FieldList': ['ANESTHESIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '123713480': {'Jtitle': 'NUTRITION RESEARCH',
#   '2021JIF': 3.876,
#   '2021JCI': 0.73,
#   'FieldList': ['NUTRITION & DIETETICS'],
#   'CitationIndexList': ['SCIE']},
#  '138083468': {'Jtitle': 'European Journal of Internal Medicine',
#   '2021JIF': 7.749,
#   '2021JCI': 1.08,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '145476921': {'Jtitle': 'ACS Nano',
#   '2021JIF': 18.027,
#   '2021JCI': 2.51,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY',
#    'CHEMISTRY, PHYSICAL',
#    'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#    'NANOSCIENCE & NANOTECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '19676749': {'Jtitle': 'MENDELEEV COMMUNICATIONS',
#   '2021JIF': 1.837,
#   '2021JCI': 0.3,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '198387837': {'Jtitle': 'European Journal of Oncology Nursing',
#   '2021JIF': 2.588,
#   '2021JCI': 0.93,
#   'FieldList': ['NURSING', 'ONCOLOGY', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']},
#  '65486112': {'Jtitle': 'ARCHIVES OF COMPUTATIONAL METHODS IN ENGINEERING',
#   '2021JIF': 8.171,
#   '2021JCI': 1.04,
#   'FieldList': ['COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#    'ENGINEERING, MULTIDISCIPLINARY',
#    'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '17753305': {'Jtitle': 'Journal of Developmental Origins of Health and Disease',
#   '2021JIF': 3.034,
#   '2021JCI': 0.74,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE']},
#  '2898446752': {'Jtitle': 'Australasian Emergency Care',
#   '2021JIF': 1.778,
#   '2021JCI': 0.74,
#   'FieldList': ['EMERGENCY MEDICINE', 'NURSING', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']},
#  '117870290': {'Jtitle': 'ACTA CHROMATOGRAPHICA',
#   '2021JIF': 2.011,
#   '2021JCI': 0.4,
#   'FieldList': ['CHEMISTRY, ANALYTICAL'],
#   'CitationIndexList': ['SCIE']},
#  '53004546': {'Jtitle': 'ENDOCRINE PATHOLOGY',
#   '2021JIF': 4.056,
#   '2021JCI': 0.97,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM', 'PATHOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '88345224': {'Jtitle': 'MATHEMATICS OF CONTROL SIGNALS AND SYSTEMS',
#   '2021JIF': 1.6,
#   '2021JCI': 0.44,
#   'FieldList': ['AUTOMATION & CONTROL SYSTEMS',
#    'ENGINEERING, ELECTRICAL & ELECTRONIC',
#    'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '146875840': {'Jtitle': 'Fottea',
#   '2021JIF': 2.429,
#   '2021JCI': 0.8,
#   'FieldList': ['PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '115815424': {'Jtitle': 'JOURNAL OF INVERTEBRATE PATHOLOGY',
#   '2021JIF': 2.795,
#   '2021JCI': 1.41,
#   'FieldList': ['ZOOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '126670327': {'Jtitle': 'KNEE',
#   '2021JIF': 2.423,
#   '2021JCI': 0.86,
#   'FieldList': ['ORTHOPEDICS', 'SPORT SCIENCES', 'SURGERY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '26186121': {'Jtitle': 'HARMFUL ALGAE',
#   '2021JIF': 5.905,
#   '2021JCI': 1.77,
#   'FieldList': ['MARINE & FRESHWATER BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '69307409': {'Jtitle': 'International Journal of Lower Extremity Wounds',
#   '2021JIF': 1.922,
#   '2021JCI': 0.61,
#   'FieldList': ['DERMATOLOGY', 'SURGERY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '108229257': {'Jtitle': 'Advanced Optical Materials',
#   '2021JIF': 10.05,
#   '2021JCI': 1.84,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY', 'OPTICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '45434965': {'Jtitle': 'HELICOBACTER',
#   '2021JIF': 5.182,
#   '2021JCI': 0.92,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY', 'MICROBIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '171488675': {'Jtitle': 'Atmospheric Research',
#   '2021JIF': 5.965,
#   '2021JCI': 1.31,
#   'FieldList': ['METEOROLOGY & ATMOSPHERIC SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '128199769': {'Jtitle': 'JOURNAL OF BONE AND MINERAL RESEARCH',
#   '2021JIF': 6.39,
#   '2021JCI': 1.47,
#   'FieldList': ['ENDOCRINOLOGY & METABOLISM'],
#   'CitationIndexList': ['SCIE']},
#  '2764449665': {'Jtitle': 'Journal of Wine Economics',
#   '2021JIF': 2.178,
#   '2021JCI': 0.79,
#   'FieldList': ['AGRICULTURAL ECONOMICS & POLICY',
#    'FOOD SCIENCE & TECHNOLOGY',
#    'ECONOMICS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']},
#  '70681891': {'Jtitle': 'JOURNAL OF MATERIALS ENGINEERING AND PERFORMANCE',
#   '2021JIF': 2.036,
#   '2021JCI': 0.33,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '5837444': {'Jtitle': 'Handchirurgie Mikrochirurgie Plastische Chirurgie',
#   '2021JIF': 0.985,
#   '2021JCI': 0.4,
#   'FieldList': ['SURGERY'],
#   'CitationIndexList': ['SCIE']},
#  '192539729': {'Jtitle': 'CLINICAL ANATOMY',
#   '2021JIF': 2.409,
#   '2021JCI': 1.08,
#   'FieldList': ['ANATOMY & MORPHOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '75054922': {'Jtitle': 'JOURNAL OF ADVANCED TRANSPORTATION',
#   '2021JIF': 2.249,
#   '2021JCI': 0.5,
#   'FieldList': ['ENGINEERING, CIVIL', 'TRANSPORTATION SCIENCE & TECHNOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '207943242': {'Jtitle': 'TRANSACTIONS OF THE AMERICAN FISHERIES SOCIETY',
#   '2021JIF': 2.2,
#   '2021JCI': 0.7,
#   'FieldList': ['FISHERIES'],
#   'CitationIndexList': ['SCIE']},
#  '2737068365': {'Jtitle': 'BioInvasions Records',
#   '2021JIF': 1.672,
#   '2021JCI': 0.44,
#   'FieldList': ['BIODIVERSITY CONSERVATION'],
#   'CitationIndexList': ['SCIE']},
#  '60606485': {'Jtitle': 'INTERNATIONAL JOURNAL OF HIGH PERFORMANCE COMPUTING APPLICATIONS',
#   '2021JIF': 2.82,
#   '2021JCI': 0.49,
#   'FieldList': ['COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#    'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#    'COMPUTER SCIENCE, THEORY & METHODS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '54368951': {'Jtitle': 'PLANT FOODS FOR HUMAN NUTRITION',
#   '2021JIF': 4.124,
#   '2021JCI': 0.82,
#   'FieldList': ['CHEMISTRY, APPLIED',
#    'FOOD SCIENCE & TECHNOLOGY',
#    'NUTRITION & DIETETICS',
#    'PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '53978400': {'Jtitle': 'Kyushu Journal of Mathematics',
#   '2021JIF': 0.388,
#   '2021JCI': 0.37,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '197106261': {'Jtitle': 'Foundations and Trends in Information Retrieval',
#   '2021JIF': 13.286,
#   '2021JCI': 3.57,
#   'FieldList': ['COMPUTER SCIENCE, INFORMATION SYSTEMS'],
#   'CitationIndexList': ['SCIE']},
#  '4210233594': {'Jtitle': 'Lancet Rheumatology',
#   '2021JIF': 35.482,
#   '2021JCI': 7.68,
#   'FieldList': ['RHEUMATOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '169733112': {'Jtitle': 'JOURNAL OF BASIC MICROBIOLOGY',
#   '2021JIF': 2.65,
#   '2021JCI': 0.44,
#   'FieldList': ['MICROBIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '9886411': {'Jtitle': 'Breastfeeding Medicine',
#   '2021JIF': 2.335,
#   '2021JCI': 0.71,
#   'FieldList': ['OBSTETRICS & GYNECOLOGY', 'PEDIATRICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2498826820': {'Jtitle': 'ANNALI DELL ISTITUTO SUPERIORE DI SANITA',
#   '2021JIF': 2.21,
#   '2021JCI': 0.5,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE']},
#  '71291065': {'Jtitle': 'Orphanet Journal of Rare Diseases',
#   '2021JIF': 4.302,
#   '2021JCI': 0.83,
#   'FieldList': ['GENETICS & HEREDITY', 'MEDICINE, RESEARCH & EXPERIMENTAL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '195318895': {'Jtitle': 'VETERINARY PATHOLOGY',
#   '2021JIF': 3.157,
#   '2021JCI': 1.04,
#   'FieldList': ['PATHOLOGY', 'VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '28609967': {'Jtitle': 'Glasnik Matematicki',
#   '2021JIF': 0.432,
#   '2021JCI': 0.4,
#   'FieldList': ['MATHEMATICS', 'MATHEMATICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '31188771': {'Jtitle': 'Genetics Research',
#   '2021JIF': 1.375,
#   '2021JCI': 0.22,
#   'FieldList': ['GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE']},
#  '179185985': {'Jtitle': 'PROCESS SAFETY AND ENVIRONMENTAL PROTECTION',
#   '2021JIF': 7.926,
#   '2021JCI': 0.95,
# ...
#   '2021JIF': 5.222,
#   '2021JCI': 0.9,
#   'FieldList': ['INFECTIOUS DISEASES', 'PHARMACOLOGY & PHARMACY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '137312515': {'Jtitle': 'BIOPROCESS AND BIOSYSTEMS ENGINEERING',
#   '2021JIF': 3.434,
#   '2021JCI': 0.64,
#   'FieldList': ['BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#    'ENGINEERING, CHEMICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '4805881': {'Jtitle': 'JOURNAL OF PURE AND APPLIED ALGEBRA',
#   '2021JIF': 0.834,
#   '2021JCI': 0.63,
#   'FieldList': ['MATHEMATICS', 'MATHEMATICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '93534766': {'Jtitle': 'Influenza and Other Respiratory Viruses',
#   '2021JIF': 5.606,
#   '2021JCI': 0.8,
#   'FieldList': ['INFECTIOUS DISEASES', 'VIROLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '156566788': {'Jtitle': 'Journal of Biological Engineering',
#   '2021JIF': 6.248,
#   '2021JCI': 0.91,
#   'FieldList': ['BIOCHEMICAL RESEARCH METHODS',
#    'BIOTECHNOLOGY & APPLIED MICROBIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '182850260': {'Jtitle': 'STOCHASTIC PROCESSES AND THEIR APPLICATIONS',
#   '2021JIF': 1.43,
#   '2021JCI': 0.7,
#   'FieldList': ['STATISTICS & PROBABILITY'],
#   'CitationIndexList': ['SCIE']},
#  '13961689': {'Jtitle': 'IEEE-ASME TRANSACTIONS ON MECHATRONICS',
#   '2021JIF': 5.867,
#   '2021JCI': 1.44,
#   'FieldList': ['AUTOMATION & CONTROL SYSTEMS',
#    'ENGINEERING, ELECTRICAL & ELECTRONIC',
#    'ENGINEERING, MANUFACTURING',
#    'ENGINEERING, MECHANICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '2764564467': {'Jtitle': 'JOURNAL OF AGRICULTURAL AND RESOURCE ECONOMICS',
#   '2021JIF': 1.826,
#   '2021JCI': 0.62,
#   'FieldList': ['AGRICULTURAL ECONOMICS & POLICY', 'ECONOMICS'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '155349577': {'Jtitle': 'Journal of Bioinformatics and Computational Biology',
#   '2021JIF': 1.204,
#   '2021JCI': 0.29,
#   'FieldList': ['MATHEMATICAL & COMPUTATIONAL BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '192650101': {'Jtitle': 'INFORMATION SCIENCES',
#   '2021JIF': 8.233,
#   '2021JCI': 2.23,
#   'FieldList': ['COMPUTER SCIENCE, INFORMATION SYSTEMS'],
#   'CitationIndexList': ['SCIE']},
#  '83672204': {'Jtitle': 'COMPTES RENDUS BIOLOGIES',
#   '2021JIF': 2.357,
#   '2021JCI': 0.58,
#   'FieldList': ['BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '57123121': {'Jtitle': 'PHYSIOLOGICAL GENOMICS',
#   '2021JIF': 4.297,
#   '2021JCI': 0.63,
#   'FieldList': ['CELL BIOLOGY', 'GENETICS & HEREDITY', 'PHYSIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '61073132': {'Jtitle': 'Assistenza Infermieristica e Ricerca',
#   '2021JIF': 0.756,
#   '2021JCI': 0.46,
#   'FieldList': ['NURSING', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '71855865': {'Jtitle': 'OPTICAL FIBER TECHNOLOGY',
#   '2021JIF': 2.8,
#   '2021JCI': 0.75,
#   'FieldList': ['ENGINEERING, ELECTRICAL & ELECTRONIC',
#    'OPTICS',
#    'TELECOMMUNICATIONS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '154343897': {'Jtitle': 'PLOS BIOLOGY',
#   '2021JIF': 9.593,
#   '2021JCI': 1.99,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY', 'BIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '80622011': {'Jtitle': 'PHARMACEUTICAL DEVELOPMENT AND TECHNOLOGY',
#   '2021JIF': 3.915,
#   '2021JCI': 0.92,
#   'FieldList': ['PHARMACOLOGY & PHARMACY'],
#   'CitationIndexList': ['SCIE']},
#  '116008648': {'Jtitle': 'PHYTOPARASITICA',
#   '2021JIF': 1.809,
#   '2021JCI': 0.54,
#   'FieldList': ['AGRONOMY', 'ENTOMOLOGY', 'PLANT SCIENCES'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '106821438': {'Jtitle': 'Journal of Gastric Cancer',
#   '2021JIF': 3.197,
#   '2021JCI': 0.54,
#   'FieldList': ['GASTROENTEROLOGY & HEPATOLOGY', 'ONCOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '72781473': {'Jtitle': 'CATALYSIS REVIEWS-SCIENCE AND ENGINEERING',
#   '2021JIF': 13.6,
#   '2021JCI': 0.59,
#   'FieldList': ['CHEMISTRY, PHYSICAL'],
#   'CitationIndexList': ['SCIE']},
#  '57082650': {'Jtitle': 'PLASMA SOURCES SCIENCE & TECHNOLOGY',
#   '2021JIF': 4.124,
#   '2021JCI': 1.26,
#   'FieldList': ['PHYSICS, FLUIDS & PLASMAS'],
#   'CitationIndexList': ['SCIE']},
#  '141734485': {'Jtitle': 'BULLETIN OF EXPERIMENTAL BIOLOGY AND MEDICINE',
#   '2021JIF': 0.737,
#   '2021JCI': 0.18,
#   'FieldList': ['MEDICINE, RESEARCH & EXPERIMENTAL'],
#   'CitationIndexList': ['SCIE']},
#  '175700853': {'Jtitle': 'COMMENTARII MATHEMATICI HELVETICI',
#   '2021JIF': 1.038,
#   '2021JCI': 0.91,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '38866342': {'Jtitle': 'AMERICAN JOURNAL OF PHYSICS',
#   '2021JIF': 0.835,
#   '2021JCI': 0.33,
#   'FieldList': ['EDUCATION, SCIENTIFIC DISCIPLINES',
#    'PHYSICS, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '85672143': {'Jtitle': 'STEEL AND COMPOSITE STRUCTURES',
#   '2021JIF': 6.144,
#   '2021JCI': 1.31,
#   'FieldList': ['CONSTRUCTION & BUILDING TECHNOLOGY',
#    'ENGINEERING, CIVIL',
#    'MATERIALS SCIENCE, COMPOSITES'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '29882555': {'Jtitle': 'Annual Review of Astronomy and Astrophysics',
#   '2021JIF': 37.226,
#   '2021JCI': 3.39,
#   'FieldList': ['ASTRONOMY & ASTROPHYSICS'],
#   'CitationIndexList': ['SCIE']},
#  '2725811': {'Jtitle': 'Artery Research',
#   '2021JIF': 0.813,
#   '2021JCI': 0.12,
#   'FieldList': ['PERIPHERAL VASCULAR DISEASE'],
#   'CitationIndexList': ['SCIE']},
#  '22017307': {'Jtitle': 'ADVANCES IN NURSING SCIENCE',
#   '2021JIF': 2.147,
#   '2021JCI': 0.95,
#   'FieldList': ['NURSING', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '115964404': {'Jtitle': 'JOURNAL OF HYPERTENSION',
#   '2021JIF': 4.776,
#   '2021JCI': 1.05,
#   'FieldList': ['PERIPHERAL VASCULAR DISEASE'],
#   'CitationIndexList': ['SCIE']},
#  '87569533': {'Jtitle': 'MECHANICS OF ADVANCED MATERIALS AND STRUCTURES',
#   '2021JIF': 3.338,
#   '2021JCI': 0.84,
#   'FieldList': ['MATERIALS SCIENCE, CHARACTERIZATION & TESTING',
#    'MATERIALS SCIENCE, COMPOSITES',
#    'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#    'MECHANICS'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']},
#  '106174089': {'Jtitle': 'Geophysics',
#   '2021JIF': 3.264,
#   '2021JCI': 0.83,
#   'FieldList': ['GEOCHEMISTRY & GEOPHYSICS'],
#   'CitationIndexList': ['SCIE']},
#  '169320561': {'Jtitle': 'Scientia Forestalis',
#   '2021JIF': 0.316,
#   '2021JCI': 0.11,
#   'FieldList': ['FORESTRY'],
#   'CitationIndexList': ['SCIE']},
#  '36275936': {'Jtitle': 'CROATICA CHEMICA ACTA',
#   '2021JIF': 0.659,
#   '2021JCI': 0.13,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '133066183': {'Jtitle': 'JOURNAL OF SHIP RESEARCH',
#   '2021JIF': 1.388,
#   '2021JCI': 0.37,
#   'FieldList': ['ENGINEERING, CIVIL', 'ENGINEERING, MARINE'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '70781564': {'Jtitle': 'PHYSICS LETTERS A',
#   '2021JIF': 2.707,
#   '2021JCI': 0.68,
#   'FieldList': ['PHYSICS, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE']},
#  '189917590': {'Jtitle': 'AIP Advances',
#   '2021JIF': 1.697,
#   '2021JCI': 0.27,
#   'FieldList': ['MATERIALS SCIENCE, MULTIDISCIPLINARY',
#    'NANOSCIENCE & NANOTECHNOLOGY',
#    'PHYSICS, APPLIED'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '155115555': {'Jtitle': 'Epigenetics & Chromatin',
#   '2021JIF': 5.488,
#   '2021JCI': 1.11,
#   'FieldList': ['GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE']},
#  '123064408': {'Jtitle': 'Advances in Carbohydrate Chemistry and Biochemistry',
#   '2021JIF': 3.714,
#   '2021JCI': 0.79,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY', 'CHEMISTRY, ORGANIC'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '113566553': {'Jtitle': 'St Petersburg Mathematical Journal',
#   '2021JIF': 0.934,
#   '2021JCI': 0.53,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '195965714': {'Jtitle': 'OCCUPATIONAL MEDICINE-OXFORD',
#   '2021JIF': 5.629,
#   '2021JCI': 0.71,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE']},
#  '37096616': {'Jtitle': 'ELECTRIC POWER COMPONENTS AND SYSTEMS',
#   '2021JIF': 1.276,
#   '2021JCI': 0.3,
#   'FieldList': ['ENGINEERING, ELECTRICAL & ELECTRONIC'],
#   'CitationIndexList': ['SCIE']},
#  '70378559': {'Jtitle': 'IMMUNOLOGIC RESEARCH',
#   '2021JIF': 4.505,
#   '2021JCI': 0.55,
#   'FieldList': ['IMMUNOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '2491942749': {'Jtitle': 'Asian Journal of Organic Chemistry',
#   '2021JIF': 3.116,
#   '2021JCI': 0.72,
#   'FieldList': ['CHEMISTRY, ORGANIC'],
#   'CitationIndexList': ['SCIE']},
#  '2898225119': {'Jtitle': 'FEBS Open Bio',
#   '2021JIF': 2.792,
#   '2021JCI': 0.44,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '188551233': {'Jtitle': 'JOURNAL OF STATISTICAL COMPUTATION AND SIMULATION',
#   '2021JIF': 1.225,
#   '2021JCI': 0.41,
#   'FieldList': ['COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#    'STATISTICS & PROBABILITY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '203131252': {'Jtitle': 'ACTA VIROLOGICA',
#   '2021JIF': 1.827,
#   '2021JCI': 0.22,
#   'FieldList': ['VIROLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '4210236237': {'Jtitle': 'Geomechanics and Geophysics for Geo-Energy and Geo-Resources',
#   '2021JIF': 4.863,
#   '2021JCI': 1.0,
#   'FieldList': ['ENERGY & FUELS',
#    'ENGINEERING, GEOLOGICAL',
#    'GEOSCIENCES, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '33142482': {'Jtitle': 'NEW ZEALAND JOURNAL OF MARINE AND FRESHWATER RESEARCH',
#   '2021JIF': 1.677,
#   '2021JCI': 0.57,
#   'FieldList': ['FISHERIES', 'MARINE & FRESHWATER BIOLOGY', 'OCEANOGRAPHY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '118474221': {'Jtitle': 'Cadernos de Saude Publica',
#   '2021JIF': 3.371,
#   '2021JCI': 0.72,
#   'FieldList': ['PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#    'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '156936584': {'Jtitle': 'Journal of Biological Dynamics',
#   '2021JIF': 2.726,
#   '2021JCI': 0.62,
#   'FieldList': ['ECOLOGY', 'MATHEMATICAL & COMPUTATIONAL BIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '27405227': {'Jtitle': 'EcoHealth',
#   '2021JIF': 4.474,
#   '2021JCI': 0.7,
#   'FieldList': ['ENVIRONMENTAL SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '178232084': {'Jtitle': 'JOURNAL OF THE ENERGY INSTITUTE',
#   '2021JIF': 6.47,
#   '2021JCI': 0.89,
#   'FieldList': ['ENERGY & FUELS'],
#   'CitationIndexList': ['SCIE']},
#  '131322813': {'Jtitle': 'JOURNAL OF FAMILY PRACTICE',
#   '2021JIF': 0.725,
#   '2021JCI': 0.18,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL', 'PRIMARY HEALTH CARE'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '57461170': {'Jtitle': 'JOURNAL OF PHYSICAL AND CHEMICAL REFERENCE DATA',
#   '2021JIF': 5.048,
#   '2021JCI': 0.67,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY',
#    'CHEMISTRY, PHYSICAL',
#    'PHYSICS, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '156858864': {'Jtitle': 'MEDICAL SCIENCE MONITOR',
#   '2021JIF': 3.386,
#   '2021JCI': 0.72,
#   'FieldList': ['MEDICINE, RESEARCH & EXPERIMENTAL'],
#   'CitationIndexList': ['SCIE']},
#  '4210208690': {'Jtitle': 'Bladder Cancer',
#   '2021JIF': 1.449,
#   '2021JCI': 0.47,
#   'FieldList': ['ONCOLOGY', 'UROLOGY & NEPHROLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2764927368': {'Jtitle': 'Journal of Civil Structural Health Monitoring',
#   '2021JIF': 3.338,
#   '2021JCI': 0.76,
#   'FieldList': ['ENGINEERING, CIVIL'],
#   'CitationIndexList': ['SCIE']},
#  '69093139': {'Jtitle': 'JOURNAL OF VETERINARY INTERNAL MEDICINE',
#   '2021JIF': 3.175,
#   '2021JCI': 1.43,
#   'FieldList': ['VETERINARY SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '133626053': {'Jtitle': 'BURNS',
#   '2021JIF': 2.609,
#   '2021JCI': 0.75,
#   'FieldList': ['CRITICAL CARE MEDICINE', 'DERMATOLOGY', 'SURGERY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '173979593': {'Jtitle': 'JOURNAL OF CHEMICAL THERMODYNAMICS',
#   '2021JIF': 3.269,
#   '2021JCI': 0.62,
#   'FieldList': ['CHEMISTRY, PHYSICAL', 'THERMODYNAMICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '109054653': {'Jtitle': 'KSCE Journal of Civil Engineering',
#   '2021JIF': 2.115,
#   '2021JCI': 0.49,
#   'FieldList': ['ENGINEERING, CIVIL'],
#   'CitationIndexList': ['SCIE']},
#  '146364893': {'Jtitle': 'Frontiers in Human Neuroscience',
#   '2021JIF': 3.473,
#   '2021JCI': 0.76,
#   'FieldList': ['NEUROSCIENCES', 'PSYCHOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '130127385': {'Jtitle': 'EUROPEAN JOURNAL OF CLINICAL MICROBIOLOGY & INFECTIOUS DISEASES',
#   '2021JIF': 5.103,
#   '2021JCI': 0.74,
#   'FieldList': ['INFECTIOUS DISEASES', 'MICROBIOLOGY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '101991353': {'Jtitle': 'Neotropical Ichthyology',
#   '2021JIF': 1.47,
#   '2021JCI': 0.84,
#   'FieldList': ['ZOOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '147407642': {'Jtitle': 'GLIA',
#   '2021JIF': 8.073,
#   '2021JCI': 1.46,
#   'FieldList': ['NEUROSCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '19793444': {'Jtitle': 'ACADEMIC MEDICINE',
#   '2021JIF': 8.034,
#   '2021JCI': 2.13,
#   'FieldList': ['EDUCATION, SCIENTIFIC DISCIPLINES',
#    'HEALTH CARE SCIENCES & SERVICES'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '61161261': {'Jtitle': 'TAIWANESE JOURNAL OF MATHEMATICS',
#   '2021JIF': 0.87,
#   '2021JCI': 0.8,
#   'FieldList': ['MATHEMATICS'],
#   'CitationIndexList': ['SCIE']},
#  '150404214': {'Jtitle': 'WIENER KLINISCHE WOCHENSCHRIFT',
#   '2021JIF': 2.275,
#   '2021JCI': 0.41,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '39580544': {'Jtitle': 'TOXICOLOGY IN VITRO',
#   '2021JIF': 3.685,
#   '2021JCI': 0.95,
#   'FieldList': ['TOXICOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '65504228': {'Jtitle': 'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES',
#   '2021JIF': 4.328,
#   '2021JCI': 0.77,
#   'FieldList': ['BIOCHEMISTRY & MOLECULAR BIOLOGY',
#    'BIOPHYSICS',
#    'CHEMISTRY, PHYSICAL'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '4210217932': {'Jtitle': 'BMJ Paediatrics Open',
#   '2021JIF': 2.922,
#   '2021JCI': 0.73,
#   'FieldList': ['PEDIATRICS'],
#   'CitationIndexList': ['SCIE']},
#  '172501725': {'Jtitle': 'ICARUS',
#   '2021JIF': 3.657,
#   '2021JCI': 0.8,
#   'FieldList': ['ASTRONOMY & ASTROPHYSICS'],
#   'CitationIndexList': ['SCIE']},
#  '185726200': {'Jtitle': 'NEUROGENETICS',
#   '2021JIF': 3.017,
#   '2021JCI': 0.76,
#   'FieldList': ['CLINICAL NEUROLOGY', 'GENETICS & HEREDITY'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '119470311': {'Jtitle': 'International Journal of Web Services Research',
#   '2021JIF': 0.771,
#   '2021JCI': 0.25,
#   'FieldList': ['COMPUTER SCIENCE, INFORMATION SYSTEMS',
#    'COMPUTER SCIENCE, SOFTWARE ENGINEERING'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  '2737064587': {'Jtitle': 'IUCrJ',
#   '2021JIF': 5.588,
#   '2021JCI': 1.31,
#   'FieldList': ['CHEMISTRY, MULTIDISCIPLINARY',
#    'CRYSTALLOGRAPHY',
#    'MATERIALS SCIENCE, MULTIDISCIPLINARY'],
#   'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']},
#  '25612858': {'Jtitle': 'EUROPEAN JOURNAL OF SOIL SCIENCE',
#   '2021JIF': 4.178,
#   '2021JCI': 0.97,
#   'FieldList': ['SOIL SCIENCE'],
#   'CitationIndexList': ['SCIE']},
#  '11324131': {'Jtitle': 'JOURNAL OF MIDWIFERY & WOMENS HEALTH',
#   '2021JIF': 2.891,
#   '2021JCI': 1.02,
#   'FieldList': ['NURSING', 'NURSING'],
#   'CitationIndexList': ['SCIE', 'SSCI']},
#  '4210219499': {'Jtitle': 'Current Climate Change Reports',
#   '2021JIF': 9.711,
#   '2021JCI': 2.07,
#   'FieldList': ['METEOROLOGY & ATMOSPHERIC SCIENCES'],
#   'CitationIndexList': ['SCIE']},
#  '198684006': {'Jtitle': 'Libyan Journal of Medicine',
#   '2021JIF': 1.743,
#   '2021JCI': 0.44,
#   'FieldList': ['MEDICINE, GENERAL & INTERNAL'],
#   'CitationIndexList': ['SCIE']},
#  '171625771': {'Jtitle': 'REJUVENATION RESEARCH',
#   '2021JIF': 3.192,
#   '2021JCI': 0.76,
#   'FieldList': ['GERIATRICS & GERONTOLOGY'],
#   'CitationIndexList': ['SCIE']},
#  '7273216': {'Jtitle': 'SCIENCE IN CONTEXT',
#   '2021JIF': 0.415,
#   '2021JCI': 0.32,
#   'FieldList': ['HISTORY & PHILOSOPHY OF SCIENCE',
#    'HISTORY & PHILOSOPHY OF SCIENCE',
#    'HISTORY & PHILOSOPHY OF SCIENCE'],
#   'CitationIndexList': ['SCIE', 'AHCI', 'SSCI']},
#  '144595962': {'Jtitle': 'APPLIED MATHEMATICS AND MECHANICS-ENGLISH EDITION',
#   '2021JIF': 3.918,
#   '2021JCI': 1.34,
#   'FieldList': ['MATHEMATICS, APPLIED', 'MECHANICS'],
#   'CitationIndexList': ['SCIE', 'SCIE']},
#  ...}

# %%
# 期刊数量分布
numJournalCateCounter = Counter()
for k,v in mag2journal.items():
    # 这里还要对FiedlList做去重
    numJournalCateCounter[len(set(v['FieldList']))] += 1
print(numJournalCateCounter)
numFields , frequency = zip(*numJournalCateCounter.items())
print(numFields, frequency)
fig, ax = plt.subplots()
bars = ax.bar(numFields, frequency)
ax.bar_label(bars)
ax.set_ylabel('期刊数量(本)', font=prop.get_name())
ax.set_xlabel('一本期刊所跨JCR学科分类数量(个)', font=prop.get_name())
ax.set_title('期刊所跨JCR学科分类数量分布', font=prop.get_name())
# ax.xaxis.set_tick_params(labelsize=24)
# ax.yaxis.set_tick_params(labelsize=24)
plt.show()
# fig.savefig("期刊所跨JCR学科数量分布.png",dpi=300)
# Out:
# Counter({1: 7902, 2: 4216, 3: 1283, 4: 315, 5: 38, 6: 8})
# (4, 1, 2, 3, 5, 6) (315, 7902, 4216, 1283, 38, 8)

# %% [markdown]
# 注意到，去除了索引后缀后，跨单JCR学科的期刊数量增加了。

# %%
mag2journal = pk.load(open('../../../DataCrossBoundaryPerspective_InterdisciplinaryResearch/mag2journal.pk', 'rb'))

# %%
from collections import Counter
mag2journaleasy = {}
for k,v in mag2journal.items():
    v['FieldList'] =set(v['FieldList'])
    mag2journaleasy[k] = v
Counter()
# Out:
# Counter()

# %%
sorted(mag2journaleasy.items(), key=lambda x: -len(x[1]['FieldList']))
# Out:
# [('69755223',
#   {'Jtitle': 'CHEMOMETRICS AND INTELLIGENT LABORATORY SYSTEMS',
#    '2021JIF': 4.175,
#    '2021JCI': 1.1,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'CHEMISTRY, ANALYTICAL',
#     'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'INSTRUMENTS & INSTRUMENTATION',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('104597489',
#   {'Jtitle': 'LANDSCAPE AND URBAN PLANNING',
#    '2021JIF': 8.119,
#    '2021JCI': 2.08,
#    'FieldList': {'ECOLOGY',
#     'ENVIRONMENTAL STUDIES',
#     'GEOGRAPHY',
#     'GEOGRAPHY, PHYSICAL',
#     'REGIONAL & URBAN PLANNING',
#     'URBAN STUDIES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI', 'SSCI', 'SSCI']}),
#  ('143846845',
#   {'Jtitle': 'NANO LETTERS',
#    '2021JIF': 12.262,
#    '2021JCI': 1.95,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('1016481467',
#   {'Jtitle': 'JOURNAL OF CULTURAL HERITAGE',
#    '2021JIF': 3.229,
#    '2021JCI': 2.29,
#    'FieldList': {'ARCHAEOLOGY',
#     'ART',
#     'CHEMISTRY, ANALYTICAL',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'SPECTROSCOPY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'AHCI', 'AHCI']}),
#  ('61773069',
#   {'Jtitle': 'JOURNAL OF CHEMOMETRICS',
#    '2021JIF': 2.5,
#    '2021JCI': 0.65,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'CHEMISTRY, ANALYTICAL',
#     'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'INSTRUMENTS & INSTRUMENTATION',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('99352657',
#   {'Jtitle': 'ADVANCED MATERIALS',
#    '2021JIF': 32.086,
#    '2021JCI': 4.18,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('135204980',
#   {'Jtitle': 'ADVANCED FUNCTIONAL MATERIALS',
#    '2021JIF': 19.924,
#    '2021JCI': 2.66,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('94619837',
#   {'Jtitle': 'Small',
#    '2021JIF': 15.153,
#    '2021JCI': 1.9,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('175287009',
#   {'Jtitle': 'INTERNATIONAL PSYCHOGERIATRICS',
#    '2021JIF': 7.191,
#    '2021JCI': 1.07,
#    'FieldList': {'GERIATRICS & GERONTOLOGY',
#     'GERONTOLOGY',
#     'PSYCHIATRY',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, CLINICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('83386566',
#   {'Jtitle': 'HUMAN FACTORS',
#    '2021JIF': 3.598,
#    '2021JCI': 0.89,
#    'FieldList': {'BEHAVIORAL SCIENCES',
#     'ENGINEERING, INDUSTRIAL',
#     'ERGONOMICS',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('81024170',
#   {'Jtitle': 'STOCHASTIC ENVIRONMENTAL RESEARCH AND RISK ASSESSMENT',
#    '2021JIF': 3.821,
#    '2021JCI': 0.89,
#    'FieldList': {'ENGINEERING, CIVIL',
#     'ENGINEERING, ENVIRONMENTAL',
#     'ENVIRONMENTAL SCIENCES',
#     'STATISTICS & PROBABILITY',
#     'WATER RESOURCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2502627819',
#   {'Jtitle': 'Advanced Energy Materials',
#    '2021JIF': 29.698,
#    '2021JCI': 3.96,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'ENERGY & FUELS',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('116100596',
#   {'Jtitle': 'RADIO SCIENCE',
#    '2021JIF': 1.678,
#    '2021JCI': 0.36,
#    'FieldList': {'ASTRONOMY & ASTROPHYSICS',
#     'GEOCHEMISTRY & GEOPHYSICS',
#     'METEOROLOGY & ATMOSPHERIC SCIENCES',
#     'REMOTE SENSING',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('56681374',
#   {'Jtitle': 'SAR AND QSAR IN ENVIRONMENTAL RESEARCH',
#    '2021JIF': 3.681,
#    '2021JCI': 0.71,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENVIRONMENTAL SCIENCES',
#     'MATHEMATICAL & COMPUTATIONAL BIOLOGY',
#     'TOXICOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('177430994',
#   {'Jtitle': 'IMAGE AND VISION COMPUTING',
#    '2021JIF': 3.86,
#    '2021JCI': 0.99,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'COMPUTER SCIENCE, SOFTWARE ENGINEERING',
#     'COMPUTER SCIENCE, THEORY & METHODS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'OPTICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('10668961',
#   {'Jtitle': 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY-ANIMAL LEARNING AND COGNITION',
#    '2021JIF': 2.088,
#    '2021JCI': 0.77,
#    'FieldList': {'BEHAVIORAL SCIENCES',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, BIOLOGICAL',
#     'PSYCHOLOGY, EXPERIMENTAL',
#     'ZOOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('144076420',
#   {'Jtitle': 'NEW GENETICS AND SOCIETY',
#    '2021JIF': 1.839,
#    '2021JCI': 0.78,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'GENETICS & HEREDITY',
#     'HISTORY & PHILOSOPHY OF SCIENCE',
#     'SOCIAL ISSUES',
#     'SOCIAL SCIENCES, BIOMEDICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI', 'SSCI']}),
#  ('105638504',
#   {'Jtitle': 'ZEITSCHRIFT FUR PSYCHOSOMATISCHE MEDIZIN UND PSYCHOTHERAPIE',
#    '2021JIF': 1.0,
#    '2021JCI': 0.67,
#    'FieldList': {'PSYCHIATRY',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, CLINICAL',
#     'PSYCHOLOGY, MULTIDISCIPLINARY',
#     'PSYCHOLOGY, PSYCHOANALYSIS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI', 'SSCI']}),
#  ('39612629',
#   {'Jtitle': 'Communications in Nonlinear Science and Numerical Simulation',
#    '2021JIF': 4.186,
#    '2021JCI': 1.7,
#    'FieldList': {'MATHEMATICS, APPLIED',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'MECHANICS',
#     'PHYSICS, FLUIDS & PLASMAS',
#     'PHYSICS, MATHEMATICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('45456423',
#   {'Jtitle': 'CLINICAL EEG AND NEUROSCIENCE',
#    '2021JIF': 2.046,
#    '2021JCI': 0.48,
#    'FieldList': {'CLINICAL NEUROLOGY',
#     'NEUROIMAGING',
#     'NEUROSCIENCES',
#     'PSYCHIATRY',
#     'PSYCHOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('55189604',
#   {'Jtitle': 'STATISTICS IN MEDICINE',
#    '2021JIF': 2.497,
#    '2021JCI': 0.64,
#    'FieldList': {'MATHEMATICAL & COMPUTATIONAL BIOLOGY',
#     'MEDICAL INFORMATICS',
#     'MEDICINE, RESEARCH & EXPERIMENTAL',
#     'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('82124767',
#   {'Jtitle': 'Nanoscale and Microscale Thermophysical Engineering',
#    '2021JIF': 4.629,
#    '2021JCI': 0.76,
#    'FieldList': {'ENGINEERING, MECHANICAL',
#     'MATERIALS SCIENCE, CHARACTERIZATION & TESTING',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED',
#     'THERMODYNAMICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('135184319',
#   {'Jtitle': 'ACS Photonics',
#    '2021JIF': 7.077,
#    '2021JCI': 1.47,
#    'FieldList': {'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'OPTICS',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('5458151',
#   {'Jtitle': 'COMBUSTION EXPLOSION AND SHOCK WAVES',
#    '2021JIF': 1.085,
#    '2021JCI': 0.19,
#    'FieldList': {'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL',
#     'ENGINEERING, MULTIDISCIPLINARY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'THERMODYNAMICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('181504447',
#   {'Jtitle': 'PETROLEUM CHEMISTRY',
#    '2021JIF': 1.258,
#    '2021JCI': 0.23,
#    'FieldList': {'CHEMISTRY, ORGANIC',
#     'CHEMISTRY, PHYSICAL',
#     'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL',
#     'ENGINEERING, PETROLEUM'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('167723465',
#   {'Jtitle': 'PSYCHOPHYSIOLOGY',
#    '2021JIF': 4.348,
#    '2021JCI': 1.07,
#    'FieldList': {'NEUROSCIENCES',
#     'PHYSIOLOGY',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, BIOLOGICAL',
#     'PSYCHOLOGY, EXPERIMENTAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('12492028',
#   {'Jtitle': 'STUDIES IN CONSERVATION',
#    '2021JIF': 0.847,
#    '2021JCI': 0.64,
#    'FieldList': {'ARCHAEOLOGY',
#     'ART',
#     'CHEMISTRY, ANALYTICAL',
#     'CHEMISTRY, APPLIED',
#     'SPECTROSCOPY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'AHCI', 'AHCI']}),
#  ('24103078',
#   {'Jtitle': 'Natural Hazards Review',
#    '2021JIF': 4.2,
#    '2021JCI': 0.88,
#    'FieldList': {'ENGINEERING, CIVIL',
#     'ENVIRONMENTAL STUDIES',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'METEOROLOGY & ATMOSPHERIC SCIENCES',
#     'WATER RESOURCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SSCI']}),
#  ('129839026',
#   {'Jtitle': 'JOURNAL OF THE AMERICAN MEDICAL INFORMATICS ASSOCIATION',
#    '2021JIF': 7.942,
#    '2021JCI': 1.83,
#    'FieldList': {'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'HEALTH CARE SCIENCES & SERVICES',
#     'INFORMATION SCIENCE & LIBRARY SCIENCE',
#     'MEDICAL INFORMATICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SSCI']}),
#  ('58069681',
#   {'Jtitle': 'IEEE TRANSACTIONS ON MEDICAL IMAGING',
#    '2021JIF': 11.037,
#    '2021JCI': 2.61,
#    'FieldList': {'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENGINEERING, BIOMEDICAL',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('65139510',
#   {'Jtitle': 'STEM CELLS',
#    '2021JIF': 5.845,
#    '2021JCI': 1.09,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'CELL & TISSUE ENGINEERING',
#     'CELL BIOLOGY',
#     'HEMATOLOGY',
#     'ONCOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('96305778',
#   {'Jtitle': 'TRANSPORTATION RESEARCH PART B-METHODOLOGICAL',
#    '2021JIF': 7.632,
#    '2021JCI': 1.69,
#    'FieldList': {'ECONOMICS',
#     'ENGINEERING, CIVIL',
#     'OPERATIONS RESEARCH & MANAGEMENT SCIENCE',
#     'TRANSPORTATION',
#     'TRANSPORTATION SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('56619941',
#   {'Jtitle': 'ENVIRONMENTAL FLUID MECHANICS',
#    '2021JIF': 2.618,
#    '2021JCI': 0.66,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'MECHANICS',
#     'METEOROLOGY & ATMOSPHERIC SCIENCES',
#     'OCEANOGRAPHY',
#     'WATER RESOURCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('116836101',
#   {'Jtitle': 'LAB ON A CHIP',
#    '2021JIF': 7.517,
#    '2021JCI': 1.36,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'CHEMISTRY, ANALYTICAL',
#     'CHEMISTRY, MULTIDISCIPLINARY',
#     'INSTRUMENTS & INSTRUMENTATION',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('76694907',
#   {'Jtitle': 'JOURNAL OF MOLECULAR GRAPHICS & MODELLING',
#    '2021JIF': 2.942,
#    '2021JCI': 0.78,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'CRYSTALLOGRAPHY',
#     'MATHEMATICAL & COMPUTATIONAL BIOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('32869529',
#   {'Jtitle': 'Combustion and Flame',
#    '2021JIF': 5.767,
#    '2021JCI': 1.22,
#    'FieldList': {'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL',
#     'ENGINEERING, MECHANICAL',
#     'ENGINEERING, MULTIDISCIPLINARY',
#     'THERMODYNAMICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('78571599',
#   {'Jtitle': 'JOURNAL OF COMPUTATIONAL BIOLOGY',
#    '2021JIF': 1.549,
#    '2021JCI': 0.42,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'MATHEMATICAL & COMPUTATIONAL BIOLOGY',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2764414965',
#   {'Jtitle': 'ACS Energy Letters',
#    '2021JIF': 23.991,
#    '2021JCI': 3.27,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'ELECTROCHEMISTRY',
#     'ENERGY & FUELS',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('156181945',
#   {'Jtitle': 'BIOSENSORS & BIOELECTRONICS',
#    '2021JIF': 12.545,
#    '2021JCI': 2.17,
#    'FieldList': {'BIOPHYSICS',
#     'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'CHEMISTRY, ANALYTICAL',
#     'ELECTROCHEMISTRY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('18714766',
#   {'Jtitle': 'Materials',
#    '2021JIF': 3.748,
#    '2021JCI': 0.62,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'METALLURGY & METALLURGICAL ENGINEERING',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('173966628',
#   {'Jtitle': 'TRANSPORTATION RESEARCH PART E-LOGISTICS AND TRANSPORTATION REVIEW',
#    '2021JIF': 10.047,
#    '2021JCI': 2.24,
#    'FieldList': {'ECONOMICS',
#     'ENGINEERING, CIVIL',
#     'OPERATIONS RESEARCH & MANAGEMENT SCIENCE',
#     'TRANSPORTATION',
#     'TRANSPORTATION SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('36838616',
#   {'Jtitle': 'CYTOTHERAPY',
#    '2021JIF': 6.196,
#    '2021JCI': 0.92,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'CELL & TISSUE ENGINEERING',
#     'CELL BIOLOGY',
#     'HEMATOLOGY',
#     'MEDICINE, RESEARCH & EXPERIMENTAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('24312346',
#   {'Jtitle': 'ATOMIZATION AND SPRAYS',
#    '2021JIF': 1.134,
#    '2021JCI': 0.23,
#    'FieldList': {'ENGINEERING, CHEMICAL',
#     'ENGINEERING, MECHANICAL',
#     'ENGINEERING, MULTIDISCIPLINARY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('129135363',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF PSYCHOPHYSIOLOGY',
#    '2021JIF': 2.903,
#    '2021JCI': 0.79,
#    'FieldList': {'NEUROSCIENCES',
#     'PHYSIOLOGY',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, BIOLOGICAL',
#     'PSYCHOLOGY, EXPERIMENTAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('82902237',
#   {'Jtitle': 'Local Environment',
#    '2021JIF': 3.59,
#    '2021JCI': 0.72,
#    'FieldList': {'ENVIRONMENTAL STUDIES',
#     'GEOGRAPHY',
#     'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY',
#     'REGIONAL & URBAN PLANNING',
#     'URBAN STUDIES'},
#    'CitationIndexList': ['SSCI', 'SSCI', 'SSCI', 'SSCI', 'SSCI']}),
#  ('180716411',
#   {'Jtitle': 'RACE & CLASS',
#    '2021JIF': 2.977,
#    '2021JCI': 0.98,
#    'FieldList': {'ANTHROPOLOGY',
#     'ETHNIC STUDIES',
#     'SOCIAL ISSUES',
#     'SOCIAL SCIENCES, INTERDISCIPLINARY',
#     'SOCIOLOGY'},
#    'CitationIndexList': ['SSCI', 'SSCI', 'SSCI', 'SSCI', 'SSCI']}),
#  ('176781058',
#   {'Jtitle': 'Mathematical Population Studies',
#    '2021JIF': 1.355,
#    '2021JCI': 0.38,
#    'FieldList': {'DEMOGRAPHY',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('2500128275',
#   {'Jtitle': 'Journal of Energy Chemistry',
#    '2021JIF': 13.599,
#    '2021JCI': 1.81,
#    'FieldList': {'CHEMISTRY, APPLIED',
#     'CHEMISTRY, PHYSICAL',
#     'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2738600312',
#   {'Jtitle': 'npj Quantum Information',
#    '2021JIF': 10.758,
#    '2021JCI': 2.21,
#    'FieldList': {'PHYSICS, APPLIED',
#     'PHYSICS, ATOMIC, MOLECULAR & CHEMICAL',
#     'PHYSICS, CONDENSED MATTER',
#     'QUANTUM SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('123979729',
#   {'Jtitle': 'BIOMEDICAL CHROMATOGRAPHY',
#    '2021JIF': 1.911,
#    '2021JCI': 0.41,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'CHEMISTRY, ANALYTICAL',
#     'PHARMACOLOGY & PHARMACY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('19081469',
#   {'Jtitle': 'Tissue Engineering Part A',
#    '2021JIF': 4.08,
#    '2021JCI': 0.71,
#    'FieldList': {'CELL & TISSUE ENGINEERING',
#     'CELL BIOLOGY',
#     'ENGINEERING, BIOMEDICAL',
#     'MATERIALS SCIENCE, BIOMATERIALS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('132957497',
#   {'Jtitle': 'IEEE JOURNAL OF OCEANIC ENGINEERING',
#    '2021JIF': 3.883,
#    '2021JCI': 1.29,
#    'FieldList': {'ENGINEERING, CIVIL',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'ENGINEERING, OCEAN',
#     'OCEANOGRAPHY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('132356188',
#   {'Jtitle': 'JOURNAL OF CARDIOTHORACIC AND VASCULAR ANESTHESIA',
#    '2021JIF': 2.894,
#    '2021JCI': 0.62,
#    'FieldList': {'ANESTHESIOLOGY',
#     'CARDIAC & CARDIOVASCULAR SYSTEMS',
#     'PERIPHERAL VASCULAR DISEASE',
#     'RESPIRATORY SYSTEM'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('106004775',
#   {'Jtitle': 'Geocarto International',
#    '2021JIF': 3.45,
#    '2021JCI': 0.79,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'REMOTE SENSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('145476921',
#   {'Jtitle': 'ACS Nano',
#    '2021JIF': 18.027,
#    '2021JCI': 2.51,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('54368951',
#   {'Jtitle': 'PLANT FOODS FOR HUMAN NUTRITION',
#    '2021JIF': 4.124,
#    '2021JCI': 0.82,
#    'FieldList': {'CHEMISTRY, APPLIED',
#     'FOOD SCIENCE & TECHNOLOGY',
#     'NUTRITION & DIETETICS',
#     'PLANT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('159568494',
#   {'Jtitle': 'COMMUNICATIONS IN SOIL SCIENCE AND PLANT ANALYSIS',
#    '2021JIF': 1.58,
#    '2021JCI': 0.38,
#    'FieldList': {'AGRONOMY',
#     'CHEMISTRY, ANALYTICAL',
#     'PLANT SCIENCES',
#     'SOIL SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('34211650',
#   {'Jtitle': 'EUROPEAN PHYSICAL JOURNAL E',
#    '2021JIF': 1.624,
#    '2021JCI': 0.34,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'PHYSICS, APPLIED',
#     'POLYMER SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('92223472',
#   {'Jtitle': 'Astin Bulletin-The Journal of the International Actuarial Association',
#    '2021JIF': 2.545,
#    '2021JCI': 0.75,
#    'FieldList': {'ECONOMICS',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('117727964',
#   {'Jtitle': 'IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing',
#    '2021JIF': 4.715,
#    '2021JCI': 1.04,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'GEOGRAPHY, PHYSICAL',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'REMOTE SENSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('44278595',
#   {'Jtitle': 'COMPUTERS IN BIOLOGY AND MEDICINE',
#    '2021JIF': 6.698,
#    '2021JCI': 1.47,
#    'FieldList': {'BIOLOGY',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENGINEERING, BIOMEDICAL',
#     'MATHEMATICAL & COMPUTATIONAL BIOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('140111354',
#   {'Jtitle': 'PHOTOGRAMMETRIC RECORD',
#    '2021JIF': 2.618,
#    '2021JCI': 0.61,
#    'FieldList': {'GEOGRAPHY, PHYSICAL',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'REMOTE SENSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('14109371',
#   {'Jtitle': 'INJURY-INTERNATIONAL JOURNAL OF THE CARE OF THE INJURED',
#    '2021JIF': 2.687,
#    '2021JCI': 0.86,
#    'FieldList': {'CRITICAL CARE MEDICINE',
#     'EMERGENCY MEDICINE',
#     'ORTHOPEDICS',
#     'SURGERY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('4210175523',
#   {'Jtitle': 'IEEE Transactions on Neural Networks and Learning Systems',
#    '2021JIF': 14.255,
#    '2021JCI': 3.01,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#     'COMPUTER SCIENCE, THEORY & METHODS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2736968195',
#   {'Jtitle': 'Heritage Science',
#    '2021JIF': 2.843,
#    '2021JCI': 2.33,
#    'FieldList': {'CHEMISTRY, ANALYTICAL',
#     'HUMANITIES, MULTIDISCIPLINARY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'SPECTROSCOPY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'AHCI']}),
#  ('63392143',
#   {'Jtitle': 'Computer Networks',
#    '2021JIF': 5.493,
#    '2021JCI': 1.28,
#    'FieldList': {'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#     'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('167262187',
#   {'Jtitle': 'Journal of Chemical Information and Modeling',
#    '2021JIF': 6.162,
#    '2021JCI': 1.36,
#    'FieldList': {'CHEMISTRY, MEDICINAL',
#     'CHEMISTRY, MULTIDISCIPLINARY',
#     'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('17577527',
#   {'Jtitle': 'Plasma Processes and Polymers',
#    '2021JIF': 3.877,
#    '2021JCI': 0.8,
#    'FieldList': {'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER',
#     'PHYSICS, FLUIDS & PLASMAS',
#     'POLYMER SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('171945920',
#   {'Jtitle': 'JOURNAL OF LAW MEDICINE & ETHICS',
#    '2021JIF': 1.604,
#    '2021JCI': 1.21,
#    'FieldList': {'ETHICS', 'LAW', 'MEDICAL ETHICS', 'MEDICINE, LEGAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('32787494',
#   {'Jtitle': 'TRAVAIL HUMAIN',
#    '2021JIF': 0.821,
#    '2021JCI': 0.14,
#    'FieldList': {'ENGINEERING, INDUSTRIAL',
#     'ERGONOMICS',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('112095004',
#   {'Jtitle': 'JOURNAL OF CHEMICAL TECHNOLOGY AND BIOTECHNOLOGY',
#    '2021JIF': 3.709,
#    '2021JCI': 0.52,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'CHEMISTRY, MULTIDISCIPLINARY',
#     'ENGINEERING, CHEMICAL',
#     'ENGINEERING, ENVIRONMENTAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('183498172',
#   {'Jtitle': 'JOURNAL OF THE FRANKLIN INSTITUTE-ENGINEERING AND APPLIED MATHEMATICS',
#    '2021JIF': 4.246,
#    '2021JCI': 1.28,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'ENGINEERING, MULTIDISCIPLINARY',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('81563257',
#   {'Jtitle': 'DEVELOPMENTAL AND COMPARATIVE IMMUNOLOGY',
#    '2021JIF': 3.605,
#    '2021JCI': 1.52,
#    'FieldList': {'FISHERIES', 'IMMUNOLOGY', 'VETERINARY SCIENCES', 'ZOOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('13961689',
#   {'Jtitle': 'IEEE-ASME TRANSACTIONS ON MECHATRONICS',
#    '2021JIF': 5.867,
#    '2021JCI': 1.44,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'ENGINEERING, MANUFACTURING',
#     'ENGINEERING, MECHANICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('87569533',
#   {'Jtitle': 'MECHANICS OF ADVANCED MATERIALS AND STRUCTURES',
#    '2021JIF': 3.338,
#    '2021JCI': 0.84,
#    'FieldList': {'MATERIALS SCIENCE, CHARACTERIZATION & TESTING',
#     'MATERIALS SCIENCE, COMPOSITES',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'MECHANICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('126920919',
#   {'Jtitle': 'IEEE Geoscience and Remote Sensing Letters',
#    '2021JIF': 5.343,
#    '2021JCI': 1.17,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'GEOCHEMISTRY & GEOPHYSICS',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'REMOTE SENSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('103895331',
#   {'Jtitle': 'NATURE MATERIALS',
#    '2021JIF': 47.656,
#    '2021JCI': 7.02,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('201145208',
#   {'Jtitle': 'SOLDERING & SURFACE MOUNT TECHNOLOGY',
#    '2021JIF': 1.494,
#    '2021JCI': 0.41,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'ENGINEERING, MANUFACTURING',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'METALLURGY & METALLURGICAL ENGINEERING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('155115410',
#   {'Jtitle': 'BIOCONJUGATE CHEMISTRY',
#    '2021JIF': 6.069,
#    '2021JCI': 0.99,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'CHEMISTRY, MULTIDISCIPLINARY',
#     'CHEMISTRY, ORGANIC'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2898348030',
#   {'Jtitle': 'Green Energy & Environment',
#    '2021JIF': 12.781,
#    '2021JCI': 1.06,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL',
#     'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2737520951',
#   {'Jtitle': 'Nanophotonics',
#    '2021JIF': 7.923,
#    '2021JCI': 1.17,
#    'FieldList': {'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'OPTICS',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('74080386',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF EATING DISORDERS',
#    '2021JIF': 5.791,
#    '2021JCI': 1.28,
#    'FieldList': {'NUTRITION & DIETETICS',
#     'PSYCHIATRY',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, CLINICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('143044361',
#   {'Jtitle': 'JOURNAL OF MOTOR BEHAVIOR',
#    '2021JIF': 1.358,
#    '2021JCI': 0.4,
#    'FieldList': {'NEUROSCIENCES',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, EXPERIMENTAL',
#     'SPORT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI']}),
#  ('137247814',
#   {'Jtitle': 'COMBUSTION THEORY AND MODELLING',
#    '2021JIF': 1.644,
#    '2021JCI': 0.38,
#    'FieldList': {'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'THERMODYNAMICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('4210216592',
#   {'Jtitle': 'EUROPEAN CELLS & MATERIALS',
#    '2021JIF': 4.325,
#    '2021JCI': 1.0,
#    'FieldList': {'CELL & TISSUE ENGINEERING',
#     'ENGINEERING, BIOMEDICAL',
#     'MATERIALS SCIENCE, BIOMATERIALS',
#     'ORTHOPEDICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('42323631',
#   {'Jtitle': 'APPLIED SURFACE SCIENCE',
#    '2021JIF': 7.392,
#    '2021JCI': 1.32,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, COATINGS & FILMS',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('146764194',
#   {'Jtitle': 'IEEE WIRELESS COMMUNICATIONS',
#    '2021JIF': 12.777,
#    '2021JCI': 3.34,
#    'FieldList': {'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#     'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('51113653',
#   {'Jtitle': 'ENGINEERING ECONOMIST',
#    '2021JIF': 1.023,
#    '2021JCI': 0.15,
#    'FieldList': {'BUSINESS',
#     'ENGINEERING, INDUSTRIAL',
#     'MANAGEMENT',
#     'OPERATIONS RESEARCH & MANAGEMENT SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('194185248',
#   {'Jtitle': 'JOURNAL OF RADIOLOGICAL PROTECTION',
#    '2021JIF': 1.559,
#    '2021JCI': 0.44,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'NUCLEAR SCIENCE & TECHNOLOGY',
#     'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH',
#     'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('52195378',
#   {'Jtitle': 'Microporous and Mesoporous Materials',
#    '2021JIF': 5.876,
#    '2021JCI': 0.92,
#    'FieldList': {'CHEMISTRY, APPLIED',
#     'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('6377669',
#   {'Jtitle': 'Soft Matter',
#    '2021JIF': 4.046,
#    '2021JCI': 0.73,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'PHYSICS, MULTIDISCIPLINARY',
#     'POLYMER SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('141804158',
#   {'Jtitle': 'Innate Immunity',
#    '2021JIF': 2.951,
#    '2021JCI': 0.49,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'IMMUNOLOGY',
#     'MEDICINE, RESEARCH & EXPERIMENTAL',
#     'MICROBIOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('95464858',
#   {'Jtitle': 'ECONOMETRICA',
#    '2021JIF': 6.383,
#    '2021JCI': 2.26,
#    'FieldList': {'ECONOMICS',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('16879113',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF PHOTOENERGY',
#    '2021JIF': 2.535,
#    '2021JCI': 0.43,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'ENERGY & FUELS',
#     'OPTICS',
#     'PHYSICS, ATOMIC, MOLECULAR & CHEMICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('4210201120',
#   {'Jtitle': 'Carbon Energy',
#    '2021JIF': 21.556,
#    '2021JCI': 1.76,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'ENERGY & FUELS',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('4210193102',
#   {'Jtitle': 'AI EDAM-ARTIFICIAL INTELLIGENCE FOR ENGINEERING DESIGN ANALYSIS AND MANUFACTURING',
#    '2021JIF': 1.634,
#    '2021JCI': 0.35,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENGINEERING, MANUFACTURING',
#     'ENGINEERING, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('43295729',
#   {'Jtitle': 'Remote Sensing',
#    '2021JIF': 5.349,
#    '2021JCI': 1.09,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'REMOTE SENSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('607880',
#   {'Jtitle': 'ENGINEERING COMPUTATIONS',
#    '2021JIF': 1.675,
#    '2021JCI': 1.39,
#    'FieldList': {'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENGINEERING, MULTIDISCIPLINARY',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'MECHANICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('992069473',
#   {'Jtitle': 'Pediatric Allergy Immunology and Pulmonology',
#    '2021JIF': 0.885,
#    '2021JCI': 0.2,
#    'FieldList': {'ALLERGY', 'IMMUNOLOGY', 'PEDIATRICS', 'RESPIRATORY SYSTEM'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('168041952',
#   {'Jtitle': 'EUROPEAN NEUROPSYCHOPHARMACOLOGY',
#    '2021JIF': 5.415,
#    '2021JCI': 1.05,
#    'FieldList': {'CLINICAL NEUROLOGY',
#     'NEUROSCIENCES',
#     'PHARMACOLOGY & PHARMACY',
#     'PSYCHIATRY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('154771817',
#   {'Jtitle': 'JOURNAL OF ANTIBIOTICS',
#    '2021JIF': 3.424,
#    '2021JCI': 0.61,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'IMMUNOLOGY',
#     'MICROBIOLOGY',
#     'PHARMACOLOGY & PHARMACY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('23181512',
#   {'Jtitle': 'Nanoscale',
#    '2021JIF': 8.307,
#    '2021JCI': 1.25,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('133335107',
#   {'Jtitle': 'MATHEMATICAL FINANCE',
#    '2021JIF': 2.894,
#    '2021JCI': 0.94,
#    'FieldList': {'BUSINESS, FINANCE',
#     'ECONOMICS',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS'},
#    'CitationIndexList': ['SCIE', 'SSCI', 'SSCI', 'SSCI']}),
#  ('144593366',
#   {'Jtitle': 'CONCEPTS IN MAGNETIC RESONANCE PART A',
#    '2021JIF': 0.643,
#    '2021JCI': 0.17,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'PHYSICS, ATOMIC, MOLECULAR & CHEMICAL',
#     'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING',
#     'SPECTROSCOPY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('128439998',
#   {'Jtitle': 'ONCOGENE',
#    '2021JIF': 8.756,
#    '2021JCI': 1.66,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'CELL BIOLOGY',
#     'GENETICS & HEREDITY',
#     'ONCOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2735447094',
#   {'Jtitle': 'JOURNALS OF GERONTOLOGY SERIES B-PSYCHOLOGICAL SCIENCES AND SOCIAL SCIENCES',
#    '2021JIF': 4.942,
#    '2021JCI': 1.61,
#    'FieldList': {'GERIATRICS & GERONTOLOGY',
#     'GERONTOLOGY',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('65425268',
#   {'Jtitle': 'JOURNAL OF ELECTROMYOGRAPHY AND KINESIOLOGY',
#    '2021JIF': 2.641,
#    '2021JCI': 0.78,
#    'FieldList': {'NEUROSCIENCES',
#     'PHYSIOLOGY',
#     'REHABILITATION',
#     'SPORT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('113313948',
#   {'Jtitle': 'ADVANCES IN SPACE RESEARCH',
#    '2021JIF': 2.611,
#    '2021JCI': 0.7,
#    'FieldList': {'ASTRONOMY & ASTROPHYSICS',
#     'ENGINEERING, AEROSPACE',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'METEOROLOGY & ATMOSPHERIC SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('99003644',
#   {'Jtitle': 'PHOTOGRAMMETRIC ENGINEERING AND REMOTE SENSING',
#    '2021JIF': 1.469,
#    '2021JCI': 0.29,
#    'FieldList': {'GEOGRAPHY, PHYSICAL',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'IMAGING SCIENCE & PHOTOGRAPHIC TECHNOLOGY',
#     'REMOTE SENSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('69822372',
#   {'Jtitle': 'JOURNAL OF COMPARATIVE PHYSIOLOGY A-NEUROETHOLOGY SENSORY NEURAL AND BEHAVIORAL PHYSIOLOGY',
#    '2021JIF': 2.389,
#    '2021JCI': 0.67,
#    'FieldList': {'BEHAVIORAL SCIENCES',
#     'NEUROSCIENCES',
#     'PHYSIOLOGY',
#     'ZOOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('172526255',
#   {'Jtitle': 'FINANCE AND STOCHASTICS',
#    '2021JIF': 2.095,
#    '2021JCI': 0.83,
#    'FieldList': {'BUSINESS, FINANCE',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('142055198',
#   {'Jtitle': 'EUROPEAN JOURNAL OF CANCER CARE',
#    '2021JIF': 2.328,
#    '2021JCI': 0.8,
#    'FieldList': {'HEALTH CARE SCIENCES & SERVICES',
#     'NURSING',
#     'ONCOLOGY',
#     'REHABILITATION'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('158028765',
#   {'Jtitle': 'MICROELECTRONIC ENGINEERING',
#    '2021JIF': 2.662,
#    '2021JCI': 0.56,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'OPTICS',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('29564236',
#   {'Jtitle': 'JOURNAL OF ETHNOPHARMACOLOGY',
#    '2021JIF': 5.195,
#    '2021JCI': 1.44,
#    'FieldList': {'CHEMISTRY, MEDICINAL',
#     'INTEGRATIVE & COMPLEMENTARY MEDICINE',
#     'PHARMACOLOGY & PHARMACY',
#     'PLANT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('59907824',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF NONLINEAR SCIENCES AND NUMERICAL SIMULATION',
#    '2021JIF': 2.156,
#    '2021JCI': 0.77,
#    'FieldList': {'ENGINEERING, MULTIDISCIPLINARY',
#     'MATHEMATICS, APPLIED',
#     'MECHANICS',
#     'PHYSICS, MATHEMATICAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('14881475',
#   {'Jtitle': 'SCIENCE AND ENGINEERING ETHICS',
#    '2021JIF': 3.777,
#    '2021JCI': 3.05,
#    'FieldList': {'ENGINEERING, MULTIDISCIPLINARY',
#     'ETHICS',
#     'HISTORY & PHILOSOPHY OF SCIENCE',
#     'MULTIDISCIPLINARY SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI']}),
#  ('132210109',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF GAME THEORY',
#    '2021JIF': 0.649,
#    '2021JCI': 0.26,
#    'FieldList': {'ECONOMICS',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('4210188408',
#   {'Jtitle': 'Digital Health',
#    '2021JIF': 4.687,
#    '2021JCI': 1.07,
#    'FieldList': {'HEALTH CARE SCIENCES & SERVICES',
#     'HEALTH POLICY & SERVICES',
#     'MEDICAL INFORMATICS',
#     'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('35512523',
#   {'Jtitle': 'ARCHAEOMETRY',
#    '2021JIF': 1.915,
#    '2021JCI': 0.73,
#    'FieldList': {'ARCHAEOLOGY',
#     'CHEMISTRY, ANALYTICAL',
#     'CHEMISTRY, INORGANIC & NUCLEAR',
#     'GEOSCIENCES, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'AHCI']}),
#  ('174819509',
#   {'Jtitle': 'SHOCK',
#    '2021JIF': 3.533,
#    '2021JCI': 1.03,
#    'FieldList': {'CRITICAL CARE MEDICINE',
#     'HEMATOLOGY',
#     'PERIPHERAL VASCULAR DISEASE',
#     'SURGERY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('117082959',
#   {'Jtitle': 'Energy & Environmental Science',
#    '2021JIF': 39.714,
#    '2021JCI': 5.24,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'ENERGY & FUELS',
#     'ENGINEERING, CHEMICAL',
#     'ENVIRONMENTAL SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('4210214890',
#   {'Jtitle': 'Environmental Progress & Sustainable Energy',
#    '2021JIF': 2.824,
#    '2021JCI': 0.38,
#    'FieldList': {'ENGINEERING, CHEMICAL',
#     'ENGINEERING, ENVIRONMENTAL',
#     'ENVIRONMENTAL SCIENCES',
#     'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('43494779',
#   {'Jtitle': 'Philosophy Ethics and Humanities in Medicine',
#    '2021JIF': 2.2,
#    '2021JCI': 1.48,
#    'FieldList': {'ETHICS',
#     'HISTORY & PHILOSOPHY OF SCIENCE',
#     'MEDICAL ETHICS',
#     'PHILOSOPHY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'AHCI', 'AHCI', 'SSCI', 'SSCI']}),
#  ('122474608',
#   {'Jtitle': 'Thermophysics and Aeromechanics',
#    '2021JIF': 0.824,
#    '2021JCI': 0.24,
#    'FieldList': {'ENGINEERING, AEROSPACE',
#     'ENGINEERING, MECHANICAL',
#     'MECHANICS',
#     'THERMODYNAMICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('87235987',
#   {'Jtitle': 'CANCER BIOTHERAPY AND RADIOPHARMACEUTICALS',
#    '2021JIF': 3.632,
#    '2021JCI': 0.81,
#    'FieldList': {'MEDICINE, RESEARCH & EXPERIMENTAL',
#     'ONCOLOGY',
#     'PHARMACOLOGY & PHARMACY',
#     'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2491293328',
#   {'Jtitle': 'Annual Review of Animal Biosciences',
#    '2021JIF': 13.341,
#    '2021JCI': 0.66,
#    'FieldList': {'AGRICULTURE, DAIRY & ANIMAL SCIENCE',
#     'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'VETERINARY SCIENCES',
#     'ZOOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('33519306',
#   {'Jtitle': 'Econometrics Journal',
#    '2021JIF': 3.071,
#    '2021JCI': 1.39,
#    'FieldList': {'ECONOMICS',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('173107507',
#   {'Jtitle': 'Biomicrofluidics',
#    '2021JIF': 3.258,
#    '2021JCI': 0.65,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'BIOPHYSICS',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, FLUIDS & PLASMAS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('197419112',
#   {'Jtitle': 'Journal of Logic Language and Information',
#    '2021JIF': 0.617,
#    '2021JCI': 0.64,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'LANGUAGE & LINGUISTICS',
#     'LOGIC',
#     'PHILOSOPHY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'AHCI', 'AHCI']}),
#  ('191329154',
#   {'Jtitle': 'DISPLAYS',
#    '2021JIF': 3.074,
#    '2021JCI': 0.67,
#    'FieldList': {'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'INSTRUMENTS & INSTRUMENTATION',
#     'OPTICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('46300952',
#   {'Jtitle': 'MEDICAL & BIOLOGICAL ENGINEERING & COMPUTING',
#    '2021JIF': 3.079,
#    '2021JCI': 0.66,
#    'FieldList': {'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENGINEERING, BIOMEDICAL',
#     'MATHEMATICAL & COMPUTATIONAL BIOLOGY',
#     'MEDICAL INFORMATICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('2734699278',
#   {'Jtitle': 'Journal of Law and the Biosciences',
#    '2021JIF': 6.066,
#    '2021JCI': 2.57,
#    'FieldList': {'ETHICS', 'LAW', 'MEDICAL ETHICS', 'MEDICINE, LEGAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('4210181446',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF GEOGRAPHICAL INFORMATION SCIENCE',
#    '2021JIF': 5.152,
#    '2021JCI': 1.36,
#    'FieldList': {'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'GEOGRAPHY',
#     'GEOGRAPHY, PHYSICAL',
#     'INFORMATION SCIENCE & LIBRARY SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('192705446',
#   {'Jtitle': 'IEEE JOURNAL OF SELECTED TOPICS IN QUANTUM ELECTRONICS',
#    '2021JIF': 4.653,
#    '2021JCI': 1.43,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'OPTICS',
#     'PHYSICS, APPLIED',
#     'QUANTUM SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('56634908',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF SPORT PSYCHOLOGY',
#    '2021JIF': 0.594,
#    '2021JCI': 0.2,
#    'FieldList': {'HOSPITALITY, LEISURE, SPORT & TOURISM',
#     'PSYCHOLOGY',
#     'PSYCHOLOGY, MULTIDISCIPLINARY',
#     'SPORT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('44643521',
#   {'Jtitle': 'COMPUTER JOURNAL',
#    '2021JIF': 1.762,
#    '2021JCI': 0.43,
#    'FieldList': {'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#     'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'COMPUTER SCIENCE, SOFTWARE ENGINEERING',
#     'COMPUTER SCIENCE, THEORY & METHODS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('44914516',
#   {'Jtitle': 'PHILOSOPHICAL MAGAZINE LETTERS',
#    '2021JIF': 1.195,
#    '2021JCI': 0.19,
#    'FieldList': {'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'METALLURGY & METALLURGICAL ENGINEERING',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('157451995',
#   {'Jtitle': 'CANCER GENE THERAPY',
#    '2021JIF': 5.854,
#    '2021JCI': 1.28,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'GENETICS & HEREDITY',
#     'MEDICINE, RESEARCH & EXPERIMENTAL',
#     'ONCOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('140928716',
#   {'Jtitle': 'PRECISION ENGINEERING-JOURNAL OF THE INTERNATIONAL SOCIETIES FOR PRECISION ENGINEERING AND NANOTECHNOLOGY',
#    '2021JIF': 3.315,
#    '2021JCI': 0.84,
#    'FieldList': {'ENGINEERING, MANUFACTURING',
#     'ENGINEERING, MULTIDISCIPLINARY',
#     'INSTRUMENTS & INSTRUMENTATION',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('14676311',
#   {'Jtitle': 'IEEE TRANSACTIONS ON SEMICONDUCTOR MANUFACTURING',
#    '2021JIF': 2.796,
#    '2021JCI': 0.63,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'ENGINEERING, MANUFACTURING',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('41709181',
#   {'Jtitle': 'AMERICAN JOURNAL OF BIOETHICS',
#    '2021JIF': 14.676,
#    '2021JCI': 3.89,
#    'FieldList': {'ETHICS',
#     'MEDICAL ETHICS',
#     'SOCIAL ISSUES',
#     'SOCIAL SCIENCES, BIOMEDICAL'},
#    'CitationIndexList': ['SCIE', 'SSCI', 'SSCI', 'SSCI']}),
#  ('99498898',
#   {'Jtitle': 'BIOELECTROCHEMISTRY',
#    '2021JIF': 5.76,
#    '2021JCI': 1.19,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'BIOLOGY',
#     'BIOPHYSICS',
#     'ELECTROCHEMISTRY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('189509794',
#   {'Jtitle': 'JOURNAL OF MATERIALS SCIENCE-MATERIALS IN ELECTRONICS',
#    '2021JIF': 2.779,
#    '2021JCI': 0.51,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'PHYSICS, APPLIED',
#     'PHYSICS, CONDENSED MATTER'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('61781353',
#   {'Jtitle': 'BRAIN AND LANGUAGE',
#    '2021JIF': 2.781,
#    '2021JCI': 1.05,
#    'FieldList': {'AUDIOLOGY & SPEECH-LANGUAGE PATHOLOGY',
#     'LINGUISTICS',
#     'NEUROSCIENCES',
#     'PSYCHOLOGY, EXPERIMENTAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('174752802',
#   {'Jtitle': 'LAW PROBABILITY & RISK',
#    '2021JIF': 0.581,
#    '2021JCI': 0.63,
#    'FieldList': {'LAW',
#     'MATHEMATICS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('2764397475',
#   {'Jtitle': 'BRITISH JOURNAL OF MATHEMATICAL & STATISTICAL PSYCHOLOGY',
#    '2021JIF': 2.41,
#    '2021JCI': 0.97,
#    'FieldList': {'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'PSYCHOLOGY, EXPERIMENTAL',
#     'PSYCHOLOGY, MATHEMATICAL',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('74751576',
#   {'Jtitle': 'MARINE GEORESOURCES & GEOTECHNOLOGY',
#    '2021JIF': 2.605,
#    '2021JCI': 0.8,
#    'FieldList': {'ENGINEERING, GEOLOGICAL',
#     'ENGINEERING, OCEAN',
#     'MINING & MINERAL PROCESSING',
#     'OCEANOGRAPHY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('4210194081',
#   {'Jtitle': 'Econometric Reviews',
#    '2021JIF': 1.605,
#    '2021JCI': 0.6,
#    'FieldList': {'ECONOMICS',
#     'MATHEMATICS, INTERDISCIPLINARY APPLICATIONS',
#     'SOCIAL SCIENCES, MATHEMATICAL METHODS',
#     'STATISTICS & PROBABILITY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('170809390',
#   {'Jtitle': 'JOURNAL OF MICROMECHANICS AND MICROENGINEERING',
#    '2021JIF': 2.282,
#    '2021JCI': 0.42,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'INSTRUMENTS & INSTRUMENTATION',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('60743949',
#   {'Jtitle': 'JOURNAL OF THE AMERICAN SOCIETY FOR MASS SPECTROMETRY',
#    '2021JIF': 3.262,
#    '2021JCI': 0.82,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'CHEMISTRY, ANALYTICAL',
#     'CHEMISTRY, PHYSICAL',
#     'SPECTROSCOPY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE', 'SCIE']}),
#  ('120158623',
#   {'Jtitle': 'STEM CELLS AND DEVELOPMENT',
# ...
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('185297315',
#   {'Jtitle': 'AGRICULTURE ECOSYSTEMS & ENVIRONMENT',
#    '2021JIF': 6.576,
#    '2021JCI': 1.7,
#    'FieldList': {'AGRICULTURE, MULTIDISCIPLINARY',
#     'ECOLOGY',
#     'ENVIRONMENTAL SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('101593883',
#   {'Jtitle': 'Clean Technologies and Environmental Policy',
#    '2021JIF': 4.7,
#    '2021JCI': 0.55,
#    'FieldList': {'ENGINEERING, ENVIRONMENTAL',
#     'ENVIRONMENTAL SCIENCES',
#     'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('66221708',
#   {'Jtitle': 'JOURNAL OF MATHEMATICAL IMAGING AND VISION',
#    '2021JIF': 1.627,
#    '2021JCI': 0.61,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'COMPUTER SCIENCE, SOFTWARE ENGINEERING',
#     'MATHEMATICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('50630504',
#   {'Jtitle': 'FOOD MICROBIOLOGY',
#    '2021JIF': 6.374,
#    '2021JCI': 1.37,
#    'FieldList': {'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'FOOD SCIENCE & TECHNOLOGY',
#     'MICROBIOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('164098111',
#   {'Jtitle': 'EXPERIMENTAL MECHANICS',
#    '2021JIF': 2.794,
#    '2021JCI': 0.66,
#    'FieldList': {'MATERIALS SCIENCE, CHARACTERIZATION & TESTING',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'MECHANICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('200334879',
#   {'Jtitle': 'DISCRETE MATHEMATICS AND THEORETICAL COMPUTER SCIENCE',
#    '2021JIF': 0.802,
#    '2021JCI': 0.3,
#    'FieldList': {'COMPUTER SCIENCE, SOFTWARE ENGINEERING',
#     'MATHEMATICS',
#     'MATHEMATICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('137835450',
#   {'Jtitle': 'WOOD AND FIBER SCIENCE',
#    '2021JIF': 1.703,
#    '2021JCI': 0.61,
#    'FieldList': {'FORESTRY',
#     'MATERIALS SCIENCE, PAPER & WOOD',
#     'MATERIALS SCIENCE, TEXTILES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('18792341',
#   {'Jtitle': 'International Journal of Fuzzy Systems',
#    '2021JIF': 4.085,
#    '2021JCI': 1.01,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'COMPUTER SCIENCE, INFORMATION SYSTEMS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('81718308',
#   {'Jtitle': 'Measurement in Physical Education and Exercise Science',
#    '2021JIF': 1.975,
#    '2021JCI': 0.88,
#    'FieldList': {'EDUCATION & EDUCATIONAL RESEARCH',
#     'HOSPITALITY, LEISURE, SPORT & TOURISM',
#     'SPORT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SSCI', 'SSCI']}),
#  ('2480266640',
#   {'Jtitle': 'IEEE Internet of Things Journal',
#    '2021JIF': 10.238,
#    '2021JCI': 2.77,
#    'FieldList': {'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('104377164',
#   {'Jtitle': 'JOURNAL OF MANIPULATIVE AND PHYSIOLOGICAL THERAPEUTICS',
#    '2021JIF': 1.3,
#    '2021JCI': 0.46,
#    'FieldList': {'HEALTH CARE SCIENCES & SERVICES',
#     'INTEGRATIVE & COMPLEMENTARY MEDICINE',
#     'REHABILITATION'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('204847658',
#   {'Jtitle': 'WATER RESOURCES RESEARCH',
#    '2021JIF': 6.159,
#    '2021JCI': 1.36,
#    'FieldList': {'ENVIRONMENTAL SCIENCES', 'LIMNOLOGY', 'WATER RESOURCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210191196',
#   {'Jtitle': 'One Earth',
#    '2021JIF': 14.944,
#    '2021JCI': 1.7,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'ENVIRONMENTAL STUDIES',
#     'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']}),
#  ('200668369',
#   {'Jtitle': 'IN VITRO CELLULAR & DEVELOPMENTAL BIOLOGY-PLANT',
#    '2021JIF': 2.347,
#    '2021JCI': 0.5,
#    'FieldList': {'CELL BIOLOGY', 'DEVELOPMENTAL BIOLOGY', 'PLANT SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210172956',
#   {'Jtitle': 'Gaceta Sanitaria',
#    '2021JIF': 2.479,
#    '2021JCI': 0.64,
#    'FieldList': {'HEALTH CARE SCIENCES & SERVICES',
#     'HEALTH POLICY & SERVICES',
#     'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('113299162',
#   {'Jtitle': 'BIOINORGANIC CHEMISTRY AND APPLICATIONS',
#    '2021JIF': 4.724,
#    '2021JCI': 1.08,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'CHEMISTRY, INORGANIC & NUCLEAR',
#     'CHEMISTRY, ORGANIC'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210180990',
#   {'Jtitle': 'BIOCHIMICA ET BIOPHYSICA ACTA-REVIEWS ON CANCER',
#    '2021JIF': 11.414,
#    '2021JCI': 1.21,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY', 'BIOPHYSICS', 'ONCOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('101278519',
#   {'Jtitle': 'AMERICAN JOURNAL OF NEURORADIOLOGY',
#    '2021JIF': 4.966,
#    '2021JCI': 1.06,
#    'FieldList': {'CLINICAL NEUROLOGY',
#     'NEUROIMAGING',
#     'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('2736865057',
#   {'Jtitle': 'Journal of Marine Science and Engineering',
#    '2021JIF': 2.744,
#    '2021JCI': 0.91,
#    'FieldList': {'ENGINEERING, MARINE', 'ENGINEERING, OCEAN', 'OCEANOGRAPHY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('176808670',
#   {'Jtitle': 'International Journal of Concrete Structures and Materials',
#    '2021JIF': 3.192,
#    '2021JCI': 0.6,
#    'FieldList': {'CONSTRUCTION & BUILDING TECHNOLOGY',
#     'ENGINEERING, CIVIL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210219247',
#   {'Jtitle': 'Structural Control & Health Monitoring',
#    '2021JIF': 6.058,
#    '2021JCI': 1.2,
#    'FieldList': {'CONSTRUCTION & BUILDING TECHNOLOGY',
#     'ENGINEERING, CIVIL',
#     'INSTRUMENTS & INSTRUMENTATION'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210190284',
#   {'Jtitle': 'ChemNanoMat',
#    '2021JIF': 3.82,
#    '2021JCI': 0.47,
#    'FieldList': {'CHEMISTRY, MULTIDISCIPLINARY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('2488537894',
#   {'Jtitle': 'IEEE Transactions on Cognitive and Developmental Systems',
#    '2021JIF': 4.546,
#    '2021JCI': 0.85,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'NEUROSCIENCES',
#     'ROBOTICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('54203203',
#   {'Jtitle': 'JOURNAL OF PALLIATIVE CARE',
#    '2021JIF': 1.98,
#    '2021JCI': 0.55,
#    'FieldList': {'HEALTH CARE SCIENCES & SERVICES',
#     'HEALTH POLICY & SERVICES',
#     'PUBLIC, ENVIRONMENTAL & OCCUPATIONAL HEALTH'},
#    'CitationIndexList': ['SCIE', 'SSCI', 'SSCI']}),
#  ('118227851',
#   {'Jtitle': 'Journal of Nano Research',
#    '2021JIF': 1.78,
#    '2021JCI': 0.38,
#    'FieldList': {'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('21442059',
#   {'Jtitle': 'BIORESOURCE TECHNOLOGY',
#    '2021JIF': 11.889,
#    '2021JCI': 1.75,
#    'FieldList': {'AGRICULTURAL ENGINEERING',
#     'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'ENERGY & FUELS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('59667848',
#   {'Jtitle': 'RANDOM STRUCTURES & ALGORITHMS',
#    '2021JIF': 1.057,
#    '2021JCI': 0.6,
#    'FieldList': {'COMPUTER SCIENCE, SOFTWARE ENGINEERING',
#     'MATHEMATICS',
#     'MATHEMATICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('200038611',
#   {'Jtitle': 'ICES JOURNAL OF MARINE SCIENCE',
#    '2021JIF': 3.906,
#    '2021JCI': 1.23,
#    'FieldList': {'FISHERIES', 'MARINE & FRESHWATER BIOLOGY', 'OCEANOGRAPHY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210202905',
#   {'Jtitle': 'Electronics',
#    '2021JIF': 2.69,
#    '2021JCI': 0.61,
#    'FieldList': {'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('129640837',
#   {'Jtitle': 'INTERNATIONAL JOURNAL OF SYSTEMS SCIENCE',
#    '2021JIF': 2.648,
#    '2021JCI': 0.59,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'COMPUTER SCIENCE, THEORY & METHODS',
#     'OPERATIONS RESEARCH & MANAGEMENT SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210224134',
#   {'Jtitle': 'Small Structures',
#    '2021JIF': 11.343,
#    '2021JCI': 0.54,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('48659482',
#   {'Jtitle': 'Optical Switching and Networking',
#    '2021JIF': 1.828,
#    '2021JCI': 0.75,
#    'FieldList': {'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'OPTICS',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('53429330',
#   {'Jtitle': 'STRESS AND HEALTH',
#    '2021JIF': 3.454,
#    '2021JCI': 0.88,
#    'FieldList': {'PSYCHIATRY', 'PSYCHOLOGY', 'PSYCHOLOGY, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI', 'SSCI']}),
#  ('115742856',
#   {'Jtitle': 'STEREOTACTIC AND FUNCTIONAL NEUROSURGERY',
#    '2021JIF': 1.643,
#    '2021JCI': 0.4,
#    'FieldList': {'NEUROIMAGING', 'NEUROSCIENCES', 'SURGERY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('185954893',
#   {'Jtitle': 'JOURNAL OF BIOLOGICAL EDUCATION',
#    '2021JIF': 1.343,
#    '2021JCI': 0.5,
#    'FieldList': {'BIOLOGY',
#     'EDUCATION & EDUCATIONAL RESEARCH',
#     'EDUCATION, SCIENTIFIC DISCIPLINES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SSCI']}),
#  ('2299478',
#   {'Jtitle': 'Journal of NeuroEngineering and Rehabilitation',
#    '2021JIF': 5.208,
#    '2021JCI': 1.3,
#    'FieldList': {'ENGINEERING, BIOMEDICAL', 'NEUROSCIENCES', 'REHABILITATION'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('4210232622',
#   {'Jtitle': 'Small Methods',
#    '2021JIF': 15.367,
#    '2021JCI': 1.34,
#    'FieldList': {'CHEMISTRY, PHYSICAL',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY',
#     'NANOSCIENCE & NANOTECHNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('72499069',
#   {'Jtitle': 'IEEE Photonics Journal',
#    '2021JIF': 2.25,
#    '2021JCI': 0.55,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'OPTICS',
#     'PHYSICS, APPLIED'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('169472558',
#   {'Jtitle': 'VIBRATIONAL SPECTROSCOPY',
#    '2021JIF': 2.382,
#    '2021JCI': 0.57,
#    'FieldList': {'CHEMISTRY, ANALYTICAL',
#     'CHEMISTRY, PHYSICAL',
#     'SPECTROSCOPY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('80660208',
#   {'Jtitle': 'BIOLOGICAL CONSERVATION',
#    '2021JIF': 7.499,
#    '2021JCI': 1.42,
#    'FieldList': {'BIODIVERSITY CONSERVATION',
#     'ECOLOGY',
#     'ENVIRONMENTAL SCIENCES'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('28101772',
#   {'Jtitle': 'JOURNAL OF PALEOLIMNOLOGY',
#    '2021JIF': 2.265,
#    '2021JCI': 0.52,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'GEOSCIENCES, MULTIDISCIPLINARY',
#     'LIMNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('193920097',
#   {'Jtitle': 'MATHEMATICAL PROGRAMMING',
#    '2021JIF': 3.06,
#    '2021JCI': 1.28,
#    'FieldList': {'COMPUTER SCIENCE, SOFTWARE ENGINEERING',
#     'MATHEMATICS, APPLIED',
#     'OPERATIONS RESEARCH & MANAGEMENT SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('2898452301',
#   {'Jtitle': 'Anthropocene',
#    '2021JIF': 3.969,
#    '2021JCI': 0.8,
#    'FieldList': {'ENVIRONMENTAL SCIENCES',
#     'GEOGRAPHY, PHYSICAL',
#     'GEOSCIENCES, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('2764718648',
#   {'Jtitle': 'Water Economics and Policy',
#    '2021JIF': 1.333,
#    '2021JCI': 0.39,
#    'FieldList': {'ECONOMICS', 'ENVIRONMENTAL STUDIES', 'WATER RESOURCES'},
#    'CitationIndexList': ['SCIE', 'SSCI', 'SSCI']}),
#  ('22312033',
#   {'Jtitle': 'IET Optoelectronics',
#    '2021JIF': 1.691,
#    '2021JCI': 0.44,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'OPTICS',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('181408163',
#   {'Jtitle': 'International Journal of Computer Assisted Radiology and Surgery',
#    '2021JIF': 3.421,
#    '2021JCI': 0.94,
#    'FieldList': {'ENGINEERING, BIOMEDICAL',
#     'RADIOLOGY, NUCLEAR MEDICINE & MEDICAL IMAGING',
#     'SURGERY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('2737336974',
#   {'Jtitle': 'Minerals',
#    '2021JIF': 2.818,
#    '2021JCI': 0.78,
#    'FieldList': {'GEOCHEMISTRY & GEOPHYSICS',
#     'MINERALOGY',
#     'MINING & MINERAL PROCESSING'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('115606517',
#   {'Jtitle': 'Frontiers in Neurorobotics',
#    '2021JIF': 3.493,
#    '2021JCI': 0.64,
#    'FieldList': {'COMPUTER SCIENCE, ARTIFICIAL INTELLIGENCE',
#     'NEUROSCIENCES',
#     'ROBOTICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('25293849',
#   {'Jtitle': 'FASEB JOURNAL',
#    '2021JIF': 5.834,
#    '2021JCI': 0.98,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'BIOLOGY',
#     'CELL BIOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('121125150',
#   {'Jtitle': 'EUROPEAN CYTOKINE NETWORK',
#    '2021JIF': 3.45,
#    '2021JCI': 0.37,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'CELL BIOLOGY',
#     'IMMUNOLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('184406644',
#   {'Jtitle': 'Bulletin of Engineering Geology and the Environment',
#    '2021JIF': 4.13,
#    '2021JCI': 0.92,
#    'FieldList': {'ENGINEERING, ENVIRONMENTAL',
#     'ENGINEERING, GEOLOGICAL',
#     'GEOSCIENCES, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('184777250',
#   {'Jtitle': 'IEEE Transactions on Industrial Informatics',
#    '2021JIF': 11.648,
#    '2021JCI': 2.51,
#    'FieldList': {'AUTOMATION & CONTROL SYSTEMS',
#     'COMPUTER SCIENCE, INTERDISCIPLINARY APPLICATIONS',
#     'ENGINEERING, INDUSTRIAL'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('7140881',
#   {'Jtitle': 'JOURNAL OF VIROLOGICAL METHODS',
#    '2021JIF': 2.623,
#    '2021JCI': 0.52,
#    'FieldList': {'BIOCHEMICAL RESEARCH METHODS',
#     'BIOTECHNOLOGY & APPLIED MICROBIOLOGY',
#     'VIROLOGY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('83853393',
#   {'Jtitle': 'International Journal of Biological Macromolecules',
#    '2021JIF': 8.025,
#    '2021JCI': 1.42,
#    'FieldList': {'BIOCHEMISTRY & MOLECULAR BIOLOGY',
#     'CHEMISTRY, APPLIED',
#     'POLYMER SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('192894947',
#   {'Jtitle': 'MOBILE NETWORKS & APPLICATIONS',
#    '2021JIF': 3.077,
#    '2021JCI': 0.87,
#    'FieldList': {'COMPUTER SCIENCE, HARDWARE & ARCHITECTURE',
#     'COMPUTER SCIENCE, INFORMATION SYSTEMS',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('95203059',
#   {'Jtitle': 'Nano Communication Networks',
#    '2021JIF': 2.783,
#    '2021JCI': 0.65,
#    'FieldList': {'ENGINEERING, ELECTRICAL & ELECTRONIC',
#     'NANOSCIENCE & NANOTECHNOLOGY',
#     'TELECOMMUNICATIONS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('130536152',
#   {'Jtitle': 'CELLULOSE',
#    '2021JIF': 6.123,
#    '2021JCI': 1.61,
#    'FieldList': {'MATERIALS SCIENCE, PAPER & WOOD',
#     'MATERIALS SCIENCE, TEXTILES',
#     'POLYMER SCIENCE'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('41852529',
#   {'Jtitle': 'JOURNAL OF VIBRATION AND ACOUSTICS-TRANSACTIONS OF THE ASME',
#    '2021JIF': 1.701,
#    '2021JCI': 0.53,
#    'FieldList': {'ACOUSTICS', 'ENGINEERING, MECHANICAL', 'MECHANICS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('178140815',
#   {'Jtitle': 'Pigment & Resin Technology',
#    '2021JIF': 1.126,
#    '2021JCI': 0.19,
#    'FieldList': {'CHEMISTRY, APPLIED',
#     'ENGINEERING, CHEMICAL',
#     'MATERIALS SCIENCE, COATINGS & FILMS'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ('2898501196',
#   {'Jtitle': 'Sustainable Materials and Technologies',
#    '2021JIF': 10.681,
#    '2021JCI': 1.34,
#    'FieldList': {'ENERGY & FUELS',
#     'GREEN & SUSTAINABLE SCIENCE & TECHNOLOGY',
#     'MATERIALS SCIENCE, MULTIDISCIPLINARY'},
#    'CitationIndexList': ['SCIE', 'SCIE', 'SCIE']}),
#  ...]
